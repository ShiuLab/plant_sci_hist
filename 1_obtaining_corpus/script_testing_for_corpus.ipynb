# %% [markdown]
# Purpose:
# * Getting basic info about pubmed XML structure.
# * Testing scripts for parsing XML files from pubmed.

# %%
# Set working directory
import gzip
from pathlib import Path 
wd = Path('/mnt/d/project/plant_sci_history/1_obtaining_corpus/')

# %% [markdown]
# ## Parse pubmed XML

# %%
#
# For: Go through an XML file and return a dictionary with PMID, title, date,
#   abstract, and journal name.
# Parameters: 
#   xml_gz_path - The Path object to an xml baseline gzipped file
# Return: 
#   pubmed_d - {pmid:[TI, AB, JO, YR, MO, DY]}
#
def parse_xml(xml_path, out_log):

    # Tags 
    AR = "PubmedArticle"    # new article
    TI = "ArticleTitle"     # title begin tag
    AB = "Abstract"
    ABe= "/Abstract"
    JO = "ISOAbbreviation"
    DA = "PubMedPubDate PubStatus=\"pubmed\""
    DAe= "/PubMedPubDate"   # Note that other PubStatus also has the
                            # same end tag.
    YR = "Year"
    MO = "Month"
    DY = "Day"
    #PM = "ArticleId IdType=\"pubmed\""
    # 11/15/21: The above is no good because citation field also used the same
    #   format.
    PM = "PMID Version="

    # {pmid:[TI, AB, JO, YR, MO, DY]}
    pubmed_d = {}
    
    # read file line by line
    input_obj = gzip.open(xml_path, 'rt') # read in text mode
    L         = input_obj.readline()
    c         = 0
    fields    = ["","","","","",""] # [TI, AB, JO, YR, MO, DY] 

    # whether DA tag is found or not before encoutering an DA end tag.
    flag_DA   = 0
    # whether AB tag is found or not.
    flag_AB   = 0
    ABSTRACT  = ""
    PMID      = ""
    # whether all the fields are obtained so ignore rest
    rec_done  = 1
    while L != "":
        L = L.strip()
        print(rec_done, [L])
        if L.startswith(f"<{AR}>") != 0:
            # This is set to make sure PMID tag is found for this article
            # and values are stored in the dictionary.
            fields   = ["","","","","",""]
            PMID = ""
            rec_done = 0
            #print("\n",L)parse_args
            if c % 1e4 == 0:
                print(f'   {c}')
            c+= 1
        elif not rec_done:
            print("in",flag_AB,L.startswith(f"<{ABe}"))
            # Title
            if L.startswith(f"<{TI}") != 0:
                fields[0] = get_value(L)
            elif L.startswith(f"<{JO}") != 0:
                fields[2] = get_value(L)
            # Deal with date
            elif L.startswith(f"<{DA}") != 0:
                flag_DA = 1
            elif L.startswith(f"<{YR}") != 0 and flag_DA == 1:
                fields[3] = get_value(L)
            elif L.startswith(f"<{MO}") != 0 and flag_DA == 1:
                fields[4] = get_value(L)
                if len(fields[4]) == 1:
                    fields[4] = "0" + fields[4]
            elif L.startswith(f"<{DY}") != 0 and flag_DA == 1:
                fields[5] = get_value(L)
                if len(fields[5]) == 1:
                    fields[5] = "0" + fields[5]        
            # Encouter Date end tag when a corresponding begin tag exists
            elif L.startswith(f"<{DAe}") != 0 and flag_DA == 1:
                flag_DA = 0
            elif L.startswith(f"<{PM}") != 0:
                PMID = get_value(L)
                if PMID not in pubmed_d:
                    pubmed_d[PMID] = []
                else:
                    out_log.write(f" Redun:{PMID}\n")
            # Deal with abstract lines
            elif L.startswith(f"<{AB}>") != 0:
                flag_AB = 1 
            # Populate abstract text if encountering the beginning abstract tag
            elif flag_AB:
                ABSTRACT += L            # Journal 
            elif L.startswith(f"<{ABe}") != 0 and flag_AB == 1:
                fields[1] = get_value(ABSTRACT)
                pubmed_d[PMID] = fields
                print("reset")
                # # all needed fields are obtained for this record, reset
                flag_AB  = 0
                ABSTRACT = ""             
                rec_done = 1
                
        L = input_obj.readline()
               
    print("  # articles:",c)
    out_log.write(f" # articles:{c}")
    
    return pubmed_d

# %%
test_xml = wd / "_test/test.xml.gz"

# %%
out_log = open("log_test","w")

# %%
pubmed_d = parse_xml(test_xml, out_log)
# Out:
# 1 ['<?xml version="1.0" encoding="utf-8"?>']
# 1 ['<!DOCTYPE PubmedArticleSet SYSTEM "http://dtd.nlm.nih.gov/ncbi/pubmed/out/pubmed_190101.dtd">']
# 1 ['<PubmedArticleSet>']
# 1 ['<PubmedArticle>']
#    0
# 0 ['<MedlineCitation Status="MEDLINE" Owner="NLM">']
# in 0 False
# 0 ['<PMID Version="1">20670107</PMID>']
# in 0 False
# 0 ['<DateCompleted>']
# in 0 False
# 0 ['<Year>2011</Year>']
# in 0 False
# 0 ['<Month>02</Month>']
# in 0 False
# 0 ['<Day>25</Day>']
# in 0 False
# 0 ['</DateCompleted>']
# in 0 False
# 0 ['<DateRevised>']
# in 0 False
# 0 ['<Year>2018</Year>']
# in 0 False
# 0 ['<Month>12</Month>']
# in 0 False
# 0 ['<Day>01</Day>']
# in 0 False
# 0 ['</DateRevised>']
# in 0 False
# 0 ['<Article PubModel="Print">']
# in 0 False
# 0 ['<Journal>']
# in 0 False
# 0 ['<ISSN IssnType="Electronic">1369-1635</ISSN>']
# in 0 False
# 0 ['<JournalIssue CitedMedium="Internet">']
# in 0 False
# 0 ['<Volume>21</Volume>']
# in 0 False
# 0 ['<Issue>7</Issue>']
# in 0 False
# 0 ['<PubDate>']
# in 0 False
# 0 ['<Year>2010</Year>']
# in 0 False
# 0 ['</PubDate>']
# in 0 False
# 0 ['</JournalIssue>']
# in 0 False
# 0 ['<Title>Platelets</Title>']
# in 0 False
# 0 ['<ISOAbbreviation>Platelets</ISOAbbreviation>']
# in 0 False
# 0 ['</Journal>']
# in 0 False
# 0 ['<ArticleTitle>Intra-individual variability in clopidogrel responsiveness in coronary artery disease patients under long term therapy.</ArticleTitle>']
# in 0 False
# 0 ['<Pagination>']
# in 0 False
# 0 ['<MedlinePgn>503-7</MedlinePgn>']
# in 0 False
# 0 ['</Pagination>']
# in 0 False
# 0 ['<ELocationID EIdType="doi" ValidYN="Y">10.3109/09537104.2010.499483</ELocationID>']
# in 0 False
# 0 ['<Abstract>']
# in 0 False
# 0 ['<AbstractText>Clopidogrel responsiveness (CR) following a loading dose (LD) predicts thrombotic events after percutaneous coronary interventions (PCI). Some of the mechanisms involved in large inter-individual variability in CR may be varied. We therefore postulated that there may be an intra-individual variability in CR. Two hundred and one patients receiving long-term therapy with aspirin and clopidogrel after drug-eluting stents PCI were prospectively included in this monocentre study along with any patient re-admitted within 12 months post-PCI. Platelet reactivity (PR) inhibition was assessed by the vasodilator phosphoprotein (VASP) index following a 600 mg loading dose of clopidogrel on each admission to determine CR (VASP 1 during the first admission and VASP 2 during re-admission). DeltaVASP = VASP 2 &amp;#x2013;VASP 1 was used to study intra-individual variability in CR. We observed that the response to a 600 mg LD of clopidogrel was poorly correlated within an individual (kappa = 0.33; p &amp;lt; 0.001 (n = 201)). Although most patients had increased platelet inhibition at the time of readmission, 35.3% of patients exhibited a decreased platelet inhibition despite chronic clopidogrel therapy and a 600 mg reload. Quartiles analysis of DeltaVASP demonstrated that insulin-treated diabetes was associated with decreased CR over time (p = 0.03). In addition to the large inter-individual variability in clopidogrel responsiveness, there is large intra-individual variability. Decreased clopidogrel responsiveness despite long-term clopidogrel therapy could be a trigger for recurrent thrombotic events.</AbstractText>']
# in 1 False
# 0 ['</Abstract>']
# in 1 True
# 0 ['<AuthorList CompleteYN="Y">']
# in 1 False
# 0 ['<Author ValidYN="Y">']
# in 1 False
# 0 ['<LastName>Arméro</LastName>']
# in 1 False
# 0 ['<ForeName>Sébastien</ForeName>']
# in 1 False
# 0 ['<Initials>S</Initials>']
# in 1 False
# 0 ['<AffiliationInfo>']
# in 1 False
# 0 ['<Affiliation>Pôle de Cardiologie, Service de Cardiologie Interventionnelle, Hôpital Universitaire Nord, AP-HM, Faculté de Médecine, Université Aix-Marseille II, France.</Affiliation>']
# in 1 False
# 0 ['</AffiliationInfo>']
# in 1 False
# 0 ['</Author>']
# in 1 False
# 0 ['<Author ValidYN="Y">']
# in 1 False
# 0 ['<LastName>Camoin Jau</LastName>']
# in 1 False
# 0 ['<ForeName>Laurence</ForeName>']
# in 1 False
# 0 ['<Initials>L</Initials>']
# in 1 False
# 0 ['</Author>']
# in 1 False
# 0 ['<Author ValidYN="Y">']
# in 1 False
# 0 ['<LastName>Omar Aït Mokhtar</LastName>']
# in 1 False
# 0 ['<ForeName>Omar</ForeName>']
# in 1 False
# 0 ['<Initials>O</Initials>']
# in 1 False
# 0 ['</Author>']
# in 1 False
# 0 ['<Author ValidYN="Y">']
# in 1 False
# 0 ['<LastName>Mancini</LastName>']
# in 1 False
# 0 ['<ForeName>Julien</ForeName>']
# in 1 False
# 0 ['<Initials>J</Initials>']
# in 1 False
# 0 ['</Author>']
# in 1 False
# 0 ['<Author ValidYN="Y">']
# in 1 False
# 0 ['<LastName>Burignat-Bonello</LastName>']
# in 1 False
# 0 ['<ForeName>Caroline</ForeName>']
# in 1 False
# 0 ['<Initials>C</Initials>']
# in 1 False
# 0 ['</Author>']
# in 1 False
# 0 ['<Author ValidYN="Y">']
# in 1 False
# 0 ['<LastName>Tahirou</LastName>']
# in 1 False
# 0 ['<ForeName>Iliassou</ForeName>']
# in 1 False
# 0 ['<Initials>I</Initials>']
# in 1 False
# 0 ['</Author>']
# in 1 False
# 0 ['<Author ValidYN="Y">']
# in 1 False
# 0 ['<LastName>Arques</LastName>']
# in 1 False
# 0 ['<ForeName>Stéphane</ForeName>']
# in 1 False
# 0 ['<Initials>S</Initials>']
# in 1 False
# 0 ['</Author>']
# in 1 False
# 0 ['<Author ValidYN="Y">']
# in 1 False
# 0 ['<LastName>Dignat-George</LastName>']
# in 1 False
# 0 ['<ForeName>Françoise</ForeName>']
# in 1 False
# 0 ['<Initials>F</Initials>']
# in 1 False
# 0 ['</Author>']
# in 1 False
# 0 ['<Author ValidYN="Y">']
# in 1 False
# 0 ['<LastName>Paganelli</LastName>']
# in 1 False
# 0 ['<ForeName>Franck</ForeName>']
# in 1 False
# 0 ['<Initials>F</Initials>']
# in 1 False
# 0 ['</Author>']
# in 1 False
# 0 ['<Author ValidYN="Y">']
# in 1 False
# 0 ['<LastName>Bonello</LastName>']
# in 1 False
# 0 ['<ForeName>Laurent</ForeName>']
# in 1 False
# 0 ['<Initials>L</Initials>']
# in 1 False
# 0 ['</Author>']
# in 1 False
# 0 ['</AuthorList>']
# in 1 False
# 0 ['<Language>eng</Language>']
# in 1 False
# 0 ['<PublicationTypeList>']
# in 1 False
# 0 ['<PublicationType UI="D016430">Clinical Trial</PublicationType>']
# in 1 False
# 0 ['<PublicationType UI="D016428">Journal Article</PublicationType>']
# in 1 False
# 0 ['</PublicationTypeList>']
# in 1 False
# 0 ['</Article>']
# in 1 False
# 0 ['<MedlineJournalInfo>']
# in 1 False
# 0 ['<Country>England</Country>']
# in 1 False
# 0 ['<MedlineTA>Platelets</MedlineTA>']
# in 1 False
# 0 ['<NlmUniqueID>9208117</NlmUniqueID>']
# in 1 False
# 0 ['<ISSNLinking>0953-7104</ISSNLinking>']
# in 1 False
# 0 ['</MedlineJournalInfo>']
# in 1 False
# 0 ['<ChemicalList>']
# in 1 False
# 0 ['<Chemical>']
# in 1 False
# 0 ['<RegistryNumber>0</RegistryNumber>']
# in 1 False
# 0 ['<NameOfSubstance UI="D015815">Cell Adhesion Molecules</NameOfSubstance>']
# in 1 False
# 0 ['</Chemical>']
# in 1 False
# 0 ['<Chemical>']
# in 1 False
# 0 ['<RegistryNumber>0</RegistryNumber>']
# in 1 False
# 0 ['<NameOfSubstance UI="D008840">Microfilament Proteins</NameOfSubstance>']
# in 1 False
# 0 ['</Chemical>']
# in 1 False
# 0 ['<Chemical>']
# in 1 False
# 0 ['<RegistryNumber>0</RegistryNumber>']
# in 1 False
# 0 ['<NameOfSubstance UI="D010750">Phosphoproteins</NameOfSubstance>']
# in 1 False
# 0 ['</Chemical>']
# in 1 False
# 0 ['<Chemical>']
# in 1 False
# 0 ['<RegistryNumber>0</RegistryNumber>']
# in 1 False
# 0 ['<NameOfSubstance UI="D010975">Platelet Aggregation Inhibitors</NameOfSubstance>']
# in 1 False
# 0 ['</Chemical>']
# in 1 False
# 0 ['<Chemical>']
# in 1 False
# 0 ['<RegistryNumber>0</RegistryNumber>']
# in 1 False
# 0 ['<NameOfSubstance UI="C087636">vasodilator-stimulated phosphoprotein</NameOfSubstance>']
# in 1 False
# 0 ['</Chemical>']
# in 1 False
# 0 ['<Chemical>']
# in 1 False
# 0 ['<RegistryNumber>A74586SNO7</RegistryNumber>']
# in 1 False
# 0 ['<NameOfSubstance UI="D000077144">Clopidogrel</NameOfSubstance>']
# in 1 False
# 0 ['</Chemical>']
# in 1 False
# 0 ['<Chemical>']
# in 1 False
# 0 ['<RegistryNumber>OM90ZUW7M1</RegistryNumber>']
# in 1 False
# 0 ['<NameOfSubstance UI="D013988">Ticlopidine</NameOfSubstance>']
# in 1 False
# 0 ['</Chemical>']
# in 1 False
# 0 ['<Chemical>']
# in 1 False
# 0 ['<RegistryNumber>R16CO5Y76E</RegistryNumber>']
# in 1 False
# 0 ['<NameOfSubstance UI="D001241">Aspirin</NameOfSubstance>']
# in 1 False
# 0 ['</Chemical>']
# in 1 False
# 0 ['</ChemicalList>']
# in 1 False
# 0 ['<CitationSubset>IM</CitationSubset>']
# in 1 False
# 0 ['<CommentsCorrectionsList>']
# in 1 False
# 0 ['<CommentsCorrections RefType="CommentIn">']
# in 1 False
# 0 ['<RefSource>Platelets. 2011;22(4):305-7</RefSource>']
# in 1 False
# 0 ['<PMID Version="1">21480769</PMID>']
# in 1 False
# 0 ['</CommentsCorrections>']
# in 1 False
# 0 ['</CommentsCorrectionsList>']
# in 1 False
# 0 ['<MeshHeadingList>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D001241" MajorTopicYN="N">Aspirin</DescriptorName>']
# in 1 False
# 0 ['<QualifierName UI="Q000008" MajorTopicYN="N">administration &amp; dosage</QualifierName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D001792" MajorTopicYN="N">Blood Platelets</DescriptorName>']
# in 1 False
# 0 ['<QualifierName UI="Q000187" MajorTopicYN="N">drug effects</QualifierName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D015815" MajorTopicYN="N">Cell Adhesion Molecules</DescriptorName>']
# in 1 False
# 0 ['<QualifierName UI="Q000097" MajorTopicYN="N">blood</QualifierName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D000077144" MajorTopicYN="N">Clopidogrel</DescriptorName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D003324" MajorTopicYN="N">Coronary Artery Disease</DescriptorName>']
# in 1 False
# 0 ['<QualifierName UI="Q000097" MajorTopicYN="N">blood</QualifierName>']
# in 1 False
# 0 ['<QualifierName UI="Q000188" MajorTopicYN="Y">drug therapy</QualifierName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D054855" MajorTopicYN="N">Drug-Eluting Stents</DescriptorName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D005260" MajorTopicYN="N">Female</DescriptorName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D006801" MajorTopicYN="N">Humans</DescriptorName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D007206" MajorTopicYN="N">Individuality</DescriptorName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D008297" MajorTopicYN="N">Male</DescriptorName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D008840" MajorTopicYN="N">Microfilament Proteins</DescriptorName>']
# in 1 False
# 0 ['<QualifierName UI="Q000097" MajorTopicYN="N">blood</QualifierName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D008875" MajorTopicYN="N">Middle Aged</DescriptorName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D010750" MajorTopicYN="N">Phosphoproteins</DescriptorName>']
# in 1 False
# 0 ['<QualifierName UI="Q000097" MajorTopicYN="N">blood</QualifierName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D010975" MajorTopicYN="N">Platelet Aggregation Inhibitors</DescriptorName>']
# in 1 False
# 0 ['<QualifierName UI="Q000008" MajorTopicYN="Y">administration &amp; dosage</QualifierName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D011446" MajorTopicYN="N">Prospective Studies</DescriptorName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D013988" MajorTopicYN="N">Ticlopidine</DescriptorName>']
# in 1 False
# 0 ['<QualifierName UI="Q000008" MajorTopicYN="N">administration &amp; dosage</QualifierName>']
# in 1 False
# 0 ['<QualifierName UI="Q000031" MajorTopicYN="Y">analogs &amp; derivatives</QualifierName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['</MeshHeadingList>']
# in 1 False
# 0 ['</MedlineCitation>']
# in 1 False
# 0 ['<PubmedData>']
# in 1 False
# 0 ['<History>']
# in 1 False
# 0 ['<PubMedPubDate PubStatus="entrez">']
# in 1 False
# 0 ['<Year>2010</Year>']
# in 1 False
# 0 ['<Month>7</Month>']
# in 1 False
# 0 ['<Day>31</Day>']
# in 1 False
# 0 ['<Hour>6</Hour>']
# in 1 False
# 0 ['<Minute>0</Minute>']
# in 1 False
# 0 ['</PubMedPubDate>']
# in 1 False
# 0 ['<PubMedPubDate PubStatus="pubmed">']
# in 1 False
# 0 ['<Year>2010</Year>']
# in 1 False
# 0 ['<Month>7</Month>']
# in 1 False
# 0 ['<Day>31</Day>']
# in 1 False
# 0 ['<Hour>6</Hour>']
# in 1 False
# 0 ['<Minute>0</Minute>']
# in 1 False
# 0 ['</PubMedPubDate>']
# in 1 False
# 0 ['<PubMedPubDate PubStatus="medline">']
# in 1 False
# 0 ['<Year>2011</Year>']
# in 1 False
# 0 ['<Month>2</Month>']
# in 1 False
# 0 ['<Day>26</Day>']
# in 1 False
# 0 ['<Hour>6</Hour>']
# in 1 False
# 0 ['<Minute>0</Minute>']
# in 1 False
# 0 ['</PubMedPubDate>']
# in 1 False
# 0 ['</History>']
# in 1 False
# 0 ['<PublicationStatus>ppublish</PublicationStatus>']
# in 1 False
# 0 ['<ArticleIdList>']
# in 1 False
# 0 ['<ArticleId IdType="pubmed">20670107</ArticleId>']
# in 1 False
# 0 ['<ArticleId IdType="doi">10.3109/09537104.2010.499483</ArticleId>']
# in 1 False
# 0 ['</ArticleIdList>']
# in 1 False
# 0 ['</PubmedData>']
# in 1 False
# 0 ['</PubmedArticle>']
# in 1 False
# 0 ['<PubmedArticle>']
# 0 ['<MedlineCitation Status="MEDLINE" Owner="NLM">']
# in 1 False
# 0 ['<PMID Version="1">20670108</PMID>']
# in 1 False
# 0 ['<DateCompleted>']
# in 1 False
# 0 ['<Year>2011</Year>']
# in 1 False
# 0 ['<Month>04</Month>']
# in 1 False
# 0 ['<Day>11</Day>']
# in 1 False
# 0 ['</DateCompleted>']
# in 1 False
# 0 ['<DateRevised>']
# in 1 False
# 0 ['<Year>2013</Year>']
# in 1 False
# 0 ['<Month>11</Month>']
# in 1 False
# 0 ['<Day>21</Day>']
# in 1 False
# 0 ['</DateRevised>']
# in 1 False
# 0 ['<Article PubModel="Print">']
# in 1 False
# 0 ['<Journal>']
# in 1 False
# 0 ['<ISSN IssnType="Electronic">1532-4184</ISSN>']
# in 1 False
# 0 ['<JournalIssue CitedMedium="Internet">']
# in 1 False
# 0 ['<Volume>38</Volume>']
# in 1 False
# 0 ['<Issue>5</Issue>']
# in 1 False
# 0 ['<PubDate>']
# in 1 False
# 0 ['<Year>2010</Year>']
# in 1 False
# 0 ['<Month>Oct</Month>']
# in 1 False
# 0 ['</PubDate>']
# in 1 False
# 0 ['</JournalIssue>']
# in 1 False
# 0 ['<Title>Artificial cells, blood substitutes, and immobilization biotechnology</Title>']
# in 1 False
# 0 ['<ISOAbbreviation>Artif Cells Blood Substit Immobil Biotechnol</ISOAbbreviation>']
# in 1 False
# 0 ['</Journal>']
# in 1 False
# 0 ['<ArticleTitle>Bioconversion of silver salt into silver nanoparticles using different microorganisms.</ArticleTitle>']
# in 1 False
# 0 ['<Pagination>']
# in 1 False
# 0 ['<MedlinePgn>259-66</MedlinePgn>']
# in 1 False
# 0 ['</Pagination>']
# in 1 False
# 0 ['<ELocationID EIdType="doi" ValidYN="Y">10.3109/10731199.2010.488633</ELocationID>']
# in 1 False
# 0 ['<Abstract>']
# in 1 False
# 0 ['<AbstractText>Abstract: Recently, silver nanoparticles have generated enough interest due to their immense usage. Until now chemical synthesis has been a fast method to produce nanoparticles, but the release of environmental pollutants has raised caution. So a more subtle biochemical approach is in research. Three microorganisms, Aspergillus flavus, Phoma exigua and Bacillus megaterium, were selected to reduce silver nitrate to silver nanoparticles in aqueous form. All three microorganisms showed varying reducing capacity, of which Phoma exigua showed the highest, when their biomass was incubated in silver nitrate for 48 hours. The nanoparticles showed all the optical and physical properties, which were analyzed by measuring the surface plasmon resonance and TEM. It was also observed that the fungal species have varied growth in silver nitrate and can be used to produce silver nanoparticles, directly incubating the inocula of fungus in the media containing silver nitrate. On comparing all the characteristics and results produced, Aspergillus flavus was found to be the most effective microorganism, which can convert the silver nitrate to silver nanoparticles in aqueous condition. The bacterial species showed no growth with incubation with silver nitrate.</AbstractText>']
# in 1 False
# 0 ['</Abstract>']
# in 1 True
# 0 ['<AuthorList CompleteYN="Y">']
# in 1 False
# 0 ['<Author ValidYN="Y">']
# in 1 False
# 0 ['<LastName>Karmakar</LastName>']
# in 1 False
# 0 ['<ForeName>Sourish</ForeName>']
# in 1 False
# 0 ['<Initials>S</Initials>']
# in 1 False
# 0 ['<AffiliationInfo>']
# in 1 False
# 0 ['<Affiliation>School of Biochemical Engineering, Institute of Technology, Banaras Hindu University, Varanasi, India.</Affiliation>']
# in 1 False
# 0 ['</AffiliationInfo>']
# in 1 False
# 0 ['</Author>']
# in 1 False
# 0 ['<Author ValidYN="Y">']
# in 1 False
# 0 ['<LastName>Kundu</LastName>']
# in 1 False
# 0 ['<ForeName>Subir</ForeName>']
# in 1 False
# 0 ['<Initials>S</Initials>']
# in 1 False
# 0 ['</Author>']
# in 1 False
# 0 ['<Author ValidYN="Y">']
# in 1 False
# 0 ['<LastName>Kundu</LastName>']
# in 1 False
# 0 ['<ForeName>Kanika</ForeName>']
# in 1 False
# 0 ['<Initials>K</Initials>']
# in 1 False
# 0 ['</Author>']
# in 1 False
# 0 ['</AuthorList>']
# in 1 False
# 0 ['<Language>eng</Language>']
# in 1 False
# 0 ['<PublicationTypeList>']
# in 1 False
# 0 ['<PublicationType UI="D016428">Journal Article</PublicationType>']
# in 1 False
# 0 ['</PublicationTypeList>']
# in 1 False
# 0 ['</Article>']
# in 1 False
# 0 ['<MedlineJournalInfo>']
# in 1 False
# 0 ['<Country>England</Country>']
# in 1 False
# 0 ['<MedlineTA>Artif Cells Blood Substit Immobil Biotechnol</MedlineTA>']
# in 1 False
# 0 ['<NlmUniqueID>9431307</NlmUniqueID>']
# in 1 False
# 0 ['<ISSNLinking>1073-1199</ISSNLinking>']
# in 1 False
# 0 ['</MedlineJournalInfo>']
# in 1 False
# 0 ['<ChemicalList>']
# in 1 False
# 0 ['<Chemical>']
# in 1 False
# 0 ['<RegistryNumber>95IT3W8JZE</RegistryNumber>']
# in 1 False
# 0 ['<NameOfSubstance UI="D012835">Silver Nitrate</NameOfSubstance>']
# in 1 False
# 0 ['</Chemical>']
# in 1 False
# 0 ['</ChemicalList>']
# in 1 False
# 0 ['<CitationSubset>IM</CitationSubset>']
# in 1 False
# 0 ['<MeshHeadingList>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D001203" MajorTopicYN="N">Ascomycota</DescriptorName>']
# in 1 False
# 0 ['<QualifierName UI="Q000187" MajorTopicYN="N">drug effects</QualifierName>']
# in 1 False
# 0 ['<QualifierName UI="Q000254" MajorTopicYN="N">growth &amp; development</QualifierName>']
# in 1 False
# 0 ['<QualifierName UI="Q000378" MajorTopicYN="Y">metabolism</QualifierName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D001231" MajorTopicYN="N">Aspergillus flavus</DescriptorName>']
# in 1 False
# 0 ['<QualifierName UI="Q000187" MajorTopicYN="N">drug effects</QualifierName>']
# in 1 False
# 0 ['<QualifierName UI="Q000254" MajorTopicYN="N">growth &amp; development</QualifierName>']
# in 1 False
# 0 ['<QualifierName UI="Q000378" MajorTopicYN="Y">metabolism</QualifierName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D001410" MajorTopicYN="N">Bacillus megaterium</DescriptorName>']
# in 1 False
# 0 ['<QualifierName UI="Q000187" MajorTopicYN="N">drug effects</QualifierName>']
# in 1 False
# 0 ['<QualifierName UI="Q000254" MajorTopicYN="N">growth &amp; development</QualifierName>']
# in 1 False
# 0 ['<QualifierName UI="Q000378" MajorTopicYN="Y">metabolism</QualifierName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D018533" MajorTopicYN="N">Biomass</DescriptorName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D001711" MajorTopicYN="N">Biotransformation</DescriptorName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D053768" MajorTopicYN="Y">Metal Nanoparticles</DescriptorName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D010084" MajorTopicYN="N">Oxidation-Reduction</DescriptorName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D012835" MajorTopicYN="N">Silver Nitrate</DescriptorName>']
# in 1 False
# 0 ['<QualifierName UI="Q000737" MajorTopicYN="Y">chemistry</QualifierName>']
# in 1 False
# 0 ['<QualifierName UI="Q000378" MajorTopicYN="Y">metabolism</QualifierName>']
# in 1 False
# 0 ['<QualifierName UI="Q000494" MajorTopicYN="N">pharmacology</QualifierName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D013056" MajorTopicYN="N">Spectrophotometry, Ultraviolet</DescriptorName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['</MeshHeadingList>']
# in 1 False
# 0 ['</MedlineCitation>']
# in 1 False
# 0 ['<PubmedData>']
# in 1 False
# 0 ['<History>']
# in 1 False
# 0 ['<PubMedPubDate PubStatus="entrez">']
# in 1 False
# 0 ['<Year>2010</Year>']
# in 1 False
# 0 ['<Month>7</Month>']
# in 1 False
# 0 ['<Day>31</Day>']
# in 1 False
# 0 ['<Hour>6</Hour>']
# in 1 False
# 0 ['<Minute>0</Minute>']
# in 1 False
# 0 ['</PubMedPubDate>']
# in 1 False
# 0 ['<PubMedPubDate PubStatus="pubmed">']
# in 1 False
# 0 ['<Year>2010</Year>']
# in 1 False
# 0 ['<Month>7</Month>']
# in 1 False
# 0 ['<Day>31</Day>']
# in 1 False
# 0 ['<Hour>6</Hour>']
# in 1 False
# 0 ['<Minute>0</Minute>']
# in 1 False
# 0 ['</PubMedPubDate>']
# in 1 False
# 0 ['<PubMedPubDate PubStatus="medline">']
# in 1 False
# 0 ['<Year>2011</Year>']
# in 1 False
# 0 ['<Month>4</Month>']
# in 1 False
# 0 ['<Day>13</Day>']
# in 1 False
# 0 ['<Hour>6</Hour>']
# in 1 False
# 0 ['<Minute>0</Minute>']
# in 1 False
# 0 ['</PubMedPubDate>']
# in 1 False
# 0 ['</History>']
# in 1 False
# 0 ['<PublicationStatus>ppublish</PublicationStatus>']
# in 1 False
# 0 ['<ArticleIdList>']
# in 1 False
# 0 ['<ArticleId IdType="pubmed">20670108</ArticleId>']
# in 1 False
# 0 ['<ArticleId IdType="doi">10.3109/10731199.2010.488633</ArticleId>']
# in 1 False
# 0 ['</ArticleIdList>']
# in 1 False
# 0 ['</PubmedData>']
# in 1 False
# 0 ['</PubmedArticle>']
# in 1 False
# 0 ['<PubmedArticle>']
# 0 ['<MedlineCitation Status="MEDLINE" Owner="NLM">']
# in 1 False
# 0 ['<PMID Version="1">20670109</PMID>']
# in 1 False
# 0 ['<DateCompleted>']
# in 1 False
# 0 ['<Year>2010</Year>']
# in 1 False
# 0 ['<Month>09</Month>']
# in 1 False
# 0 ['<Day>22</Day>']
# in 1 False
# 0 ['</DateCompleted>']
# in 1 False
# 0 ['<DateRevised>']
# in 1 False
# 0 ['<Year>2010</Year>']
# in 1 False
# 0 ['<Month>09</Month>']
# in 1 False
# 0 ['<Day>02</Day>']
# in 1 False
# 0 ['</DateRevised>']
# in 1 False
# 0 ['<Article PubModel="Print">']
# in 1 False
# 0 ['<Journal>']
# in 1 False
# 0 ['<ISSN IssnType="Electronic">1362-3095</ISSN>']
# in 1 False
# 0 ['<JournalIssue CitedMedium="Internet">']
# in 1 False
# 0 ['<Volume>86</Volume>']
# in 1 False
# 0 ['<Issue>9</Issue>']
# in 1 False
# 0 ['<PubDate>']
# in 1 False
# 0 ['<Year>2010</Year>']
# in 1 False
# 0 ['<Month>Sep</Month>']
# in 1 False
# 0 ['</PubDate>']
# in 1 False
# 0 ['</JournalIssue>']
# in 1 False
# 0 ['<Title>International journal of radiation biology</Title>']
# in 1 False
# 0 ['<ISOAbbreviation>Int J Radiat Biol</ISOAbbreviation>']
# in 1 False
# 0 ['</Journal>']
# in 1 False
# 0 ['<ArticleTitle>Protection against radiation-induced oxidative damage by an ethanolic extract of Nigella sativa L.</ArticleTitle>']
# in 1 False
# 0 ['<Pagination>']
# in 1 False
# 0 ['<MedlinePgn>719-31</MedlinePgn>']
# in 1 False
# 0 ['</Pagination>']
# in 1 False
# 0 ['<ELocationID EIdType="doi" ValidYN="Y">10.3109/09553002.2010.484480</ELocationID>']
# in 1 False
# 0 ['<Abstract>']
# in 1 False
# 0 ['<AbstractText Label="PURPOSE" NlmCategory="OBJECTIVE">An ethanolic extract of Nigella sativa L. (EE-NS) was investigated for its antioxidant properties and radioprotective effects against gamma-radiation-induced oxidative damage.</AbstractText>']
# in 1 False
# 0 ['<AbstractText Label="MATERIALS AND METHODS" NlmCategory="METHODS">The radical scavenging activity of the extract was measured by 2,2-diphenyl-1-picrylhydrazyl (DPPH), deoxyribose degradation and plasmid relaxation assays in a cell-free system. DNA damage studies were performed using a single cell gel electrophoresis (SCGE) assay and micronuclei (MN) formation. Moreover, the alterations in lipid peroxidation and antioxidant enzymes were measured by biochemical methods.</AbstractText>']
# in 1 False
# 0 ['<AbstractText Label="RESULTS" NlmCategory="RESULTS">EE-NS showed significant free radical scavenging and protection against DNA damage in cell free systems. Ex vivo treatment of mouse splenic lymphocytes with an ethanolic extract of N. sativa 1 h prior to irradiation (2 Gy) showed significant prevention of the formation of lipid-peroxides and intracellular reactive oxygen species (ROS), which correlated with radiation-induced apoptosis. Moreover, radiation-induced DNA damage was significantly prevented in splenocytes pre-treated with EE-NS. Swiss albino mice fed orally with the different doses of EE-NS (0-100 mg/kg bw) for five consecutive days followed by 2 Gy whole body irradiation (WBI) showed significant protection against oxidative injury to spleen and liver as measured by lipid peroxidation and the activity of antioxidant enzymes. These results were correlated with the prevention of DNA damage as measured by bone marrow micronuclei assay. Our results suggest that oral feeding of extract resulted in increased survival in mice exposed to WBI (7.5 Gy).</AbstractText>']
# in 1 False
# 0 ['<AbstractText Label="CONCLUSION" NlmCategory="CONCLUSIONS">The results obtained from the different experimental systems suggest the radioprotective ability of EE-NS involving prevention of radiation-induced oxidative damage.</AbstractText>']
# in 1 False
# 0 ['</Abstract>']
# in 1 True
# 0 ['<AuthorList CompleteYN="Y">']
# in 1 False
# 0 ['<Author ValidYN="Y">']
# in 1 False
# 0 ['<LastName>Rastogi</LastName>']
# in 1 False
# 0 ['<ForeName>Lori</ForeName>']
# in 1 False
# 0 ['<Initials>L</Initials>']
# in 1 False
# 0 ['<AffiliationInfo>']
# in 1 False
# 0 ['<Affiliation>Radiation Biology and Health Sciences Division, Bhabha Atomic Research Center, Mumbai, India.</Affiliation>']
# in 1 False
# 0 ['</AffiliationInfo>']
# in 1 False
# 0 ['</Author>']
# in 1 False
# 0 ['<Author ValidYN="Y">']
# in 1 False
# 0 ['<LastName>Feroz</LastName>']
# in 1 False
# 0 ['<ForeName>Shaikh</ForeName>']
# in 1 False
# 0 ['<Initials>S</Initials>']
# in 1 False
# 0 ['</Author>']
# in 1 False
# 0 ['<Author ValidYN="Y">']
# in 1 False
# 0 ['<LastName>Pandey</LastName>']
# in 1 False
# 0 ['<ForeName>Badri Narain</ForeName>']
# in 1 False
# 0 ['<Initials>BN</Initials>']
# in 1 False
# 0 ['</Author>']
# in 1 False
# 0 ['<Author ValidYN="Y">']
# in 1 False
# 0 ['<LastName>Jagtap</LastName>']
# in 1 False
# 0 ['<ForeName>Arti</ForeName>']
# in 1 False
# 0 ['<Initials>A</Initials>']
# in 1 False
# 0 ['</Author>']
# in 1 False
# 0 ['<Author ValidYN="Y">']
# in 1 False
# 0 ['<LastName>Mishra</LastName>']
# in 1 False
# 0 ['<ForeName>Kaushala Prasad</ForeName>']
# in 1 False
# 0 ['<Initials>KP</Initials>']
# in 1 False
# 0 ['</Author>']
# in 1 False
# 0 ['</AuthorList>']
# in 1 False
# 0 ['<Language>eng</Language>']
# in 1 False
# 0 ['<PublicationTypeList>']
# in 1 False
# 0 ['<PublicationType UI="D016428">Journal Article</PublicationType>']
# in 1 False
# 0 ['</PublicationTypeList>']
# in 1 False
# 0 ['</Article>']
# in 1 False
# 0 ['<MedlineJournalInfo>']
# in 1 False
# 0 ['<Country>England</Country>']
# in 1 False
# 0 ['<MedlineTA>Int J Radiat Biol</MedlineTA>']
# in 1 False
# 0 ['<NlmUniqueID>8809243</NlmUniqueID>']
# in 1 False
# 0 ['<ISSNLinking>0955-3002</ISSNLinking>']
# in 1 False
# 0 ['</MedlineJournalInfo>']
# in 1 False
# 0 ['<ChemicalList>']
# in 1 False
# 0 ['<Chemical>']
# in 1 False
# 0 ['<RegistryNumber>0</RegistryNumber>']
# in 1 False
# 0 ['<NameOfSubstance UI="D000975">Antioxidants</NameOfSubstance>']
# in 1 False
# 0 ['</Chemical>']
# in 1 False
# 0 ['<Chemical>']
# in 1 False
# 0 ['<RegistryNumber>0</RegistryNumber>']
# in 1 False
# 0 ['<NameOfSubstance UI="D016166">Free Radical Scavengers</NameOfSubstance>']
# in 1 False
# 0 ['</Chemical>']
# in 1 False
# 0 ['<Chemical>']
# in 1 False
# 0 ['<RegistryNumber>0</RegistryNumber>']
# in 1 False
# 0 ['<NameOfSubstance UI="D010936">Plant Extracts</NameOfSubstance>']
# in 1 False
# 0 ['</Chemical>']
# in 1 False
# 0 ['<Chemical>']
# in 1 False
# 0 ['<RegistryNumber>0</RegistryNumber>']
# in 1 False
# 0 ['<NameOfSubstance UI="D011837">Radiation-Protective Agents</NameOfSubstance>']
# in 1 False
# 0 ['</Chemical>']
# in 1 False
# 0 ['</ChemicalList>']
# in 1 False
# 0 ['<CitationSubset>IM</CitationSubset>']
# in 1 False
# 0 ['<CitationSubset>S</CitationSubset>']
# in 1 False
# 0 ['<MeshHeadingList>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D000818" MajorTopicYN="N">Animals</DescriptorName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D000975" MajorTopicYN="N">Antioxidants</DescriptorName>']
# in 1 False
# 0 ['<QualifierName UI="Q000494" MajorTopicYN="Y">pharmacology</QualifierName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D017209" MajorTopicYN="N">Apoptosis</DescriptorName>']
# in 1 False
# 0 ['<QualifierName UI="Q000187" MajorTopicYN="N">drug effects</QualifierName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D002474" MajorTopicYN="N">Cell-Free System</DescriptorName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D004249" MajorTopicYN="N">DNA Damage</DescriptorName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D005260" MajorTopicYN="N">Female</DescriptorName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D016166" MajorTopicYN="N">Free Radical Scavengers</DescriptorName>']
# in 1 False
# 0 ['<QualifierName UI="Q000494" MajorTopicYN="N">pharmacology</QualifierName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D007958" MajorTopicYN="N">Leukocyte Count</DescriptorName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D015227" MajorTopicYN="N">Lipid Peroxidation</DescriptorName>']
# in 1 False
# 0 ['<QualifierName UI="Q000187" MajorTopicYN="N">drug effects</QualifierName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D051379" MajorTopicYN="N">Mice</DescriptorName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D031881" MajorTopicYN="Y">Nigella sativa</DescriptorName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D010084" MajorTopicYN="N">Oxidation-Reduction</DescriptorName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D010936" MajorTopicYN="N">Plant Extracts</DescriptorName>']
# in 1 False
# 0 ['<QualifierName UI="Q000494" MajorTopicYN="Y">pharmacology</QualifierName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D011837" MajorTopicYN="N">Radiation-Protective Agents</DescriptorName>']
# in 1 False
# 0 ['<QualifierName UI="Q000494" MajorTopicYN="Y">pharmacology</QualifierName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D014916" MajorTopicYN="N">Whole-Body Irradiation</DescriptorName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['</MeshHeadingList>']
# in 1 False
# 0 ['</MedlineCitation>']
# in 1 False
# 0 ['<PubmedData>']
# in 1 False
# 0 ['<History>']
# in 1 False
# 0 ['<PubMedPubDate PubStatus="entrez">']
# in 1 False
# 0 ['<Year>2010</Year>']
# in 1 False
# 0 ['<Month>7</Month>']
# in 1 False
# 0 ['<Day>31</Day>']
# in 1 False
# 0 ['<Hour>6</Hour>']
# in 1 False
# 0 ['<Minute>0</Minute>']
# in 1 False
# 0 ['</PubMedPubDate>']
# in 1 False
# 0 ['<PubMedPubDate PubStatus="pubmed">']
# in 1 False
# 0 ['<Year>2010</Year>']
# in 1 False
# 0 ['<Month>7</Month>']
# in 1 False
# 0 ['<Day>31</Day>']
# in 1 False
# 0 ['<Hour>6</Hour>']
# in 1 False
# 0 ['<Minute>0</Minute>']
# in 1 False
# 0 ['</PubMedPubDate>']
# in 1 False
# 0 ['<PubMedPubDate PubStatus="medline">']
# in 1 False
# 0 ['<Year>2010</Year>']
# in 1 False
# 0 ['<Month>9</Month>']
# in 1 False
# 0 ['<Day>24</Day>']
# in 1 False
# 0 ['<Hour>6</Hour>']
# in 1 False
# 0 ['<Minute>0</Minute>']
# in 1 False
# 0 ['</PubMedPubDate>']
# in 1 False
# 0 ['</History>']
# in 1 False
# 0 ['<PublicationStatus>ppublish</PublicationStatus>']
# in 1 False
# 0 ['<ArticleIdList>']
# in 1 False
# 0 ['<ArticleId IdType="pubmed">20670109</ArticleId>']
# in 1 False
# 0 ['<ArticleId IdType="doi">10.3109/09553002.2010.484480</ArticleId>']
# in 1 False
# 0 ['</ArticleIdList>']
# in 1 False
# 0 ['</PubmedData>']
# in 1 False
# 0 ['</PubmedArticle>']
# in 1 False
# 0 ['<PubmedArticle>']
# 0 ['<MedlineCitation Status="MEDLINE" Owner="NLM">']
# in 1 False
# 0 ['<PMID Version="1">20670110</PMID>']
# in 1 False
# 0 ['<DateCompleted>']
# in 1 False
# 0 ['<Year>2010</Year>']
# in 1 False
# 0 ['<Month>11</Month>']
# in 1 False
# 0 ['<Day>24</Day>']
# in 1 False
# 0 ['</DateCompleted>']
# in 1 False
# 0 ['<DateRevised>']
# in 1 False
# 0 ['<Year>2013</Year>']
# in 1 False
# 0 ['<Month>11</Month>']
# in 1 False
# 0 ['<Day>21</Day>']
# in 1 False
# 0 ['</DateRevised>']
# in 1 False
# 0 ['<Article PubModel="Print-Electronic">']
# in 1 False
# 0 ['<Journal>']
# in 1 False
# 0 ['<ISSN IssnType="Electronic">1362-3095</ISSN>']
# in 1 False
# 0 ['<JournalIssue CitedMedium="Internet">']
# in 1 False
# 0 ['<Volume>86</Volume>']
# in 1 False
# 0 ['<Issue>11</Issue>']
# in 1 False
# 0 ['<PubDate>']
# in 1 False
# 0 ['<Year>2010</Year>']
# in 1 False
# 0 ['<Month>Nov</Month>']
# in 1 False
# 0 ['</PubDate>']
# in 1 False
# 0 ['</JournalIssue>']
# in 1 False
# 0 ['<Title>International journal of radiation biology</Title>']
# in 1 False
# 0 ['<ISOAbbreviation>Int J Radiat Biol</ISOAbbreviation>']
# in 1 False
# 0 ['</Journal>']
# in 1 False
# 0 ['<ArticleTitle>Natural radionuclides in fish species from surface water of Bagjata and Banduhurang uranium mining areas, East Singhbhum, Jharkhand, India.</ArticleTitle>']
# in 1 False
# 0 ['<Pagination>']
# in 1 False
# 0 ['<MedlinePgn>946-56</MedlinePgn>']
# in 1 False
# 0 ['</Pagination>']
# in 1 False
# 0 ['<ELocationID EIdType="doi" ValidYN="Y">10.3109/09553002.2010.492490</ELocationID>']
# in 1 False
# 0 ['<Abstract>']
# in 1 False
# 0 ['<AbstractText Label="PURPOSE" NlmCategory="OBJECTIVE">To study the natural radionuclides in the freshwater fish samples around the uranium mining areas of Bagjata and Banduhurang, East Singhbhum, Jharkhand, India.</AbstractText>']
# in 1 False
# 0 ['<AbstractText Label="MATERIALS AND METHODS" NlmCategory="METHODS">The naturally occurring radioisotopes of uranium, U(nat), consisting of (234)U, (235)U and (238)U; (226)Ra, (230)Th and (210)Po were analysed in the fish samples from the surface water of Bagjata and Banduhurang mining areas after acid digestion. The ingestion dose, concentration factor and excess lifetime cancer risk of the radionuclides were estimated.</AbstractText>']
# in 1 False
# 0 ['<AbstractText Label="RESULTS" NlmCategory="RESULTS">The geometric mean activity of U(nat), (226)Ra, (230)Th and (210)Po in the fish samples was found to be 0.05, 0.19, 0.29 and 0.95 Bq kg(-1)(fresh) (Becquerel per kilogram fresh fish), respectively, in the Bagjata mining area, while for Banduhurang mining area it was estimated to be 0.08, 0.41, 0.22 and 2.48 Bq kg(-1)(fresh), respectively. The ingestion dose was computed to be 1.88 and 4.16 μSvY(-1), respectively, for both the areas which is much below the 1 mSv limit set in the new International Commission on Radiological Protection (ICRP) recommendations. The estimation of the Concentration Factors (CF) reveal that the CF from water is greater than 1 l/kg(-1)in most of the cases while from sediment CF is less than 1. The excess individual lifetime cancer risk due to the consumption of fish was calculated to be 2.53 × 10(-5) and 6.48 × 10(-5), respectively, for Bagjata and Banduhurang areas, which is within the acceptable excess individual lifetime cancer risk value of 1 × 10(-4).</AbstractText>']
# in 1 False
# 0 ['<AbstractText Label="CONCLUSION" NlmCategory="CONCLUSIONS">The study confirms that current levels of radioactivity do not pose a significant radiological risk to freshwater fish consumers.</AbstractText>']
# in 1 False
# 0 ['</Abstract>']
# in 1 True
# 0 ['<AuthorList CompleteYN="Y">']
# in 1 False
# 0 ['<Author ValidYN="Y">']
# in 1 False
# 0 ['<LastName>Giri</LastName>']
# in 1 False
# 0 ['<ForeName>Soma</ForeName>']
# in 1 False
# 0 ['<Initials>S</Initials>']
# in 1 False
# 0 ['<AffiliationInfo>']
# in 1 False
# 0 ['<Affiliation>Department of Environmental Science and Engineering, Indian School of Mines, Dhanbad, India. soma0307@gmail.com</Affiliation>']
# in 1 False
# 0 ['</AffiliationInfo>']
# in 1 False
# 0 ['</Author>']
# in 1 False
# 0 ['<Author ValidYN="Y">']
# in 1 False
# 0 ['<LastName>Singh</LastName>']
# in 1 False
# 0 ['<ForeName>Gurdeep</ForeName>']
# in 1 False
# 0 ['<Initials>G</Initials>']
# in 1 False
# 0 ['</Author>']
# in 1 False
# 0 ['<Author ValidYN="Y">']
# in 1 False
# 0 ['<LastName>Jha</LastName>']
# in 1 False
# 0 ['<ForeName>V N</ForeName>']
# in 1 False
# 0 ['<Initials>VN</Initials>']
# in 1 False
# 0 ['</Author>']
# in 1 False
# 0 ['<Author ValidYN="Y">']
# in 1 False
# 0 ['<LastName>Tripathi</LastName>']
# in 1 False
# 0 ['<ForeName>R M</ForeName>']
# in 1 False
# 0 ['<Initials>RM</Initials>']
# in 1 False
# 0 ['</Author>']
# in 1 False
# 0 ['</AuthorList>']
# in 1 False
# 0 ['<Language>eng</Language>']
# in 1 False
# 0 ['<PublicationTypeList>']
# in 1 False
# 0 ['<PublicationType UI="D016428">Journal Article</PublicationType>']
# in 1 False
# 0 ['<PublicationType UI="D013485">Research Support, Non-U.S. Gov\'t</PublicationType>']
# in 1 False
# 0 ['</PublicationTypeList>']
# in 1 False
# 0 ['<ArticleDate DateType="Electronic">']
# in 1 False
# 0 ['<Year>2010</Year>']
# in 1 False
# 0 ['<Month>07</Month>']
# in 1 False
# 0 ['<Day>29</Day>']
# in 1 False
# 0 ['</ArticleDate>']
# in 1 False
# 0 ['</Article>']
# in 1 False
# 0 ['<MedlineJournalInfo>']
# in 1 False
# 0 ['<Country>England</Country>']
# in 1 False
# 0 ['<MedlineTA>Int J Radiat Biol</MedlineTA>']
# in 1 False
# 0 ['<NlmUniqueID>8809243</NlmUniqueID>']
# in 1 False
# 0 ['<ISSNLinking>0955-3002</ISSNLinking>']
# in 1 False
# 0 ['</MedlineJournalInfo>']
# in 1 False
# 0 ['<ChemicalList>']
# in 1 False
# 0 ['<Chemical>']
# in 1 False
# 0 ['<RegistryNumber>0</RegistryNumber>']
# in 1 False
# 0 ['<NameOfSubstance UI="D011868">Radioisotopes</NameOfSubstance>']
# in 1 False
# 0 ['</Chemical>']
# in 1 False
# 0 ['<Chemical>']
# in 1 False
# 0 ['<RegistryNumber>4OC371KSTK</RegistryNumber>']
# in 1 False
# 0 ['<NameOfSubstance UI="D014501">Uranium</NameOfSubstance>']
# in 1 False
# 0 ['</Chemical>']
# in 1 False
# 0 ['<Chemical>']
# in 1 False
# 0 ['<RegistryNumber>60YU5MIG9W</RegistryNumber>']
# in 1 False
# 0 ['<NameOfSubstance UI="D013910">Thorium</NameOfSubstance>']
# in 1 False
# 0 ['</Chemical>']
# in 1 False
# 0 ['<Chemical>']
# in 1 False
# 0 ['<RegistryNumber>DQY03U61EJ</RegistryNumber>']
# in 1 False
# 0 ['<NameOfSubstance UI="D011059">Polonium</NameOfSubstance>']
# in 1 False
# 0 ['</Chemical>']
# in 1 False
# 0 ['<Chemical>']
# in 1 False
# 0 ['<RegistryNumber>W90AYD6R3Q</RegistryNumber>']
# in 1 False
# 0 ['<NameOfSubstance UI="D011883">Radium</NameOfSubstance>']
# in 1 False
# 0 ['</Chemical>']
# in 1 False
# 0 ['</ChemicalList>']
# in 1 False
# 0 ['<CitationSubset>IM</CitationSubset>']
# in 1 False
# 0 ['<CitationSubset>S</CitationSubset>']
# in 1 False
# 0 ['<MeshHeadingList>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D000818" MajorTopicYN="N">Animals</DescriptorName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D004307" MajorTopicYN="N">Dose-Response Relationship, Radiation</DescriptorName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D005399" MajorTopicYN="Y">Fishes</DescriptorName>']
# in 1 False
# 0 ['<QualifierName UI="Q000145" MajorTopicYN="N">classification</QualifierName>']
# in 1 False
# 0 ['<QualifierName UI="Q000378" MajorTopicYN="N">metabolism</QualifierName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D005507" MajorTopicYN="N">Food Contamination, Radioactive</DescriptorName>']
# in 1 False
# 0 ['<QualifierName UI="Q000032" MajorTopicYN="Y">analysis</QualifierName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D005618" MajorTopicYN="N">Fresh Water</DescriptorName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D005843" MajorTopicYN="N">Geography</DescriptorName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D007194" MajorTopicYN="N" Type="Geographic">India</DescriptorName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D008906" MajorTopicYN="Y">Mining</DescriptorName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D011059" MajorTopicYN="N">Polonium</DescriptorName>']
# in 1 False
# 0 ['<QualifierName UI="Q000032" MajorTopicYN="N">analysis</QualifierName>']
# in 1 False
# 0 ['<QualifierName UI="Q000633" MajorTopicYN="N">toxicity</QualifierName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D011868" MajorTopicYN="N">Radioisotopes</DescriptorName>']
# in 1 False
# 0 ['<QualifierName UI="Q000009" MajorTopicYN="N">adverse effects</QualifierName>']
# in 1 False
# 0 ['<QualifierName UI="Q000032" MajorTopicYN="Y">analysis</QualifierName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D011883" MajorTopicYN="N">Radium</DescriptorName>']
# in 1 False
# 0 ['<QualifierName UI="Q000032" MajorTopicYN="N">analysis</QualifierName>']
# in 1 False
# 0 ['<QualifierName UI="Q000633" MajorTopicYN="N">toxicity</QualifierName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D018570" MajorTopicYN="N">Risk Assessment</DescriptorName>']
# in 1 False
# 0 ['<QualifierName UI="Q000379" MajorTopicYN="N">methods</QualifierName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D012307" MajorTopicYN="N">Risk Factors</DescriptorName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D013910" MajorTopicYN="N">Thorium</DescriptorName>']
# in 1 False
# 0 ['<QualifierName UI="Q000032" MajorTopicYN="N">analysis</QualifierName>']
# in 1 False
# 0 ['<QualifierName UI="Q000633" MajorTopicYN="N">toxicity</QualifierName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D014501" MajorTopicYN="N">Uranium</DescriptorName>']
# in 1 False
# 0 ['<QualifierName UI="Q000032" MajorTopicYN="Y">analysis</QualifierName>']
# in 1 False
# 0 ['<QualifierName UI="Q000633" MajorTopicYN="N">toxicity</QualifierName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['</MeshHeadingList>']
# in 1 False
# 0 ['</MedlineCitation>']
# in 1 False
# 0 ['<PubmedData>']
# in 1 False
# 0 ['<History>']
# in 1 False
# 0 ['<PubMedPubDate PubStatus="entrez">']
# in 1 False
# 0 ['<Year>2010</Year>']
# in 1 False
# 0 ['<Month>7</Month>']
# in 1 False
# 0 ['<Day>31</Day>']
# in 1 False
# 0 ['<Hour>6</Hour>']
# in 1 False
# 0 ['<Minute>0</Minute>']
# in 1 False
# 0 ['</PubMedPubDate>']
# in 1 False
# 0 ['<PubMedPubDate PubStatus="pubmed">']
# in 1 False
# 0 ['<Year>2010</Year>']
# in 1 False
# 0 ['<Month>7</Month>']
# in 1 False
# 0 ['<Day>31</Day>']
# in 1 False
# 0 ['<Hour>6</Hour>']
# in 1 False
# 0 ['<Minute>0</Minute>']
# in 1 False
# 0 ['</PubMedPubDate>']
# in 1 False
# 0 ['<PubMedPubDate PubStatus="medline">']
# in 1 False
# 0 ['<Year>2010</Year>']
# in 1 False
# 0 ['<Month>12</Month>']
# in 1 False
# 0 ['<Day>14</Day>']
# in 1 False
# 0 ['<Hour>6</Hour>']
# in 1 False
# 0 ['<Minute>0</Minute>']
# in 1 False
# 0 ['</PubMedPubDate>']
# in 1 False
# 0 ['</History>']
# in 1 False
# 0 ['<PublicationStatus>ppublish</PublicationStatus>']
# in 1 False
# 0 ['<ArticleIdList>']
# in 1 False
# 0 ['<ArticleId IdType="pubmed">20670110</ArticleId>']
# in 1 False
# 0 ['<ArticleId IdType="doi">10.3109/09553002.2010.492490</ArticleId>']
# in 1 False
# 0 ['</ArticleIdList>']
# in 1 False
# 0 ['</PubmedData>']
# in 1 False
# 0 ['</PubmedArticle>']
# in 1 False
# 0 ['<PubmedArticle>']
# 0 ['<MedlineCitation Status="MEDLINE" Owner="NLM">']
# in 1 False
# 0 ['<PMID Version="1">20670111</PMID>']
# in 1 False
# 0 ['<DateCompleted>']
# in 1 False
# 0 ['<Year>2010</Year>']
# in 1 False
# 0 ['<Month>11</Month>']
# in 1 False
# 0 ['<Day>24</Day>']
# in 1 False
# 0 ['</DateCompleted>']
# in 1 False
# 0 ['<DateRevised>']
# in 1 False
# 0 ['<Year>2018</Year>']
# in 1 False
# 0 ['<Month>12</Month>']
# in 1 False
# 0 ['<Day>01</Day>']
# in 1 False
# 0 ['</DateRevised>']
# in 1 False
# 0 ['<Article PubModel="Print-Electronic">']
# in 1 False
# 0 ['<Journal>']
# in 1 False
# 0 ['<ISSN IssnType="Electronic">1362-3095</ISSN>']
# in 1 False
# 0 ['<JournalIssue CitedMedium="Internet">']
# in 1 False
# 0 ['<Volume>86</Volume>']
# in 1 False
# 0 ['<Issue>11</Issue>']
# in 1 False
# 0 ['<PubDate>']
# in 1 False
# 0 ['<Year>2010</Year>']
# in 1 False
# 0 ['<Month>Nov</Month>']
# in 1 False
# 0 ['</PubDate>']
# in 1 False
# 0 ['</JournalIssue>']
# in 1 False
# 0 ['<Title>International journal of radiation biology</Title>']
# in 1 False
# 0 ['<ISOAbbreviation>Int J Radiat Biol</ISOAbbreviation>']
# in 1 False
# 0 ['</Journal>']
# in 1 False
# 0 ['<ArticleTitle>Inter-chromosomal variation in aberration frequencies in human lymphocytes exposed to charged particles of LET between 0.5 and 55 keV/μm.</ArticleTitle>']
# in 1 False
# 0 ['<Pagination>']
# in 1 False
# 0 ['<MedlinePgn>975-85</MedlinePgn>']
# in 1 False
# 0 ['</Pagination>']
# in 1 False
# 0 ['<ELocationID EIdType="doi" ValidYN="Y">10.3109/09553002.2010.496028</ELocationID>']
# in 1 False
# 0 ['<Abstract>']
# in 1 False
# 0 ['<AbstractText Label="PURPOSE" NlmCategory="OBJECTIVE">To investigate the distribution of chromosomal aberrations in chromosomes 2, 8 and 14 induced by charged particles, using the fluorescence in situ hybridisation (FISH) technique.</AbstractText>']
# in 1 False
# 0 ['<AbstractText Label="METHODS" NlmCategory="METHODS">Irradiation of peripheral blood from six healthy volunteers (four male and two female) was performed at the accelerators of the Joint Institute for Nuclear Research (JINR) in Dubna (Russia). Whole blood samples were irradiated with 2 and 3 Gy of protons (170 MeV/nucleon (n), linear energy transfer (LET) ≈ 0.5 keV/μm), 3.5 Gy of (12)C ions (480 MeV/n, LET = 10.6 keV/μm), 3 Gy of (12)C ions 500 MeV/n, LET = 12 keV/μm), 4 Gy of (7)Li ions (30 MeV/n, LET ≈ 20 keV/μm) and 3 Gy of (11)B ions (32 MeV/n, LET ≈ 55 keV/μm). Chromosomal aberrations were analysed in metaphase and prematurely condensed chromosomes (PCC) induced in G(2)-cells using calyculin A. Chromosomes 2, 8 and 14 were painted in different colours and aberrations scored with the help of an image-analysis system.</AbstractText>']
# in 1 False
# 0 ['<AbstractText Label="RESULTS" NlmCategory="RESULTS">Chromosome 2 was generally less sensitive than expected on the basis of its DNA content. A higher than expected frequency of exchanges was found in chromosomes 8 and 14. On average, the dicentric frequency in chromosome 2 was higher than the translocation frequency, whereas variable dicentric to translocation ratios were observed in chromosomes 8 and 14. When aberrations in all painted chromosomes were summed up the ratio was close to 1. The frequency of complex aberrations correlated with LET.</AbstractText>']
# in 1 False
# 0 ['<AbstractText Label="CONCLUSION" NlmCategory="CONCLUSIONS">In lymphocytes of donors studied in this work chromosome 2 appears to be consistently less sensitive to protons and heavy ions than chromosomes 8 and 14. Complex aberrations appear to be a potential marker of radiation quality.</AbstractText>']
# in 1 False
# 0 ['</Abstract>']
# in 1 True
# 0 ['<AuthorList CompleteYN="Y">']
# in 1 False
# 0 ['<Author ValidYN="Y">']
# in 1 False
# 0 ['<LastName>Deperas-Kaminska</LastName>']
# in 1 False
# 0 ['<ForeName>Marta</ForeName>']
# in 1 False
# 0 ['<Initials>M</Initials>']
# in 1 False
# 0 ['<AffiliationInfo>']
# in 1 False
# 0 ['<Affiliation>Joint Institute for Nuclear Research, Dubna, Russia.</Affiliation>']
# in 1 False
# 0 ['</AffiliationInfo>']
# in 1 False
# 0 ['</Author>']
# in 1 False
# 0 ['<Author ValidYN="Y">']
# in 1 False
# 0 ['<LastName>Zaytseva</LastName>']
# in 1 False
# 0 ['<ForeName>Ekaterina M</ForeName>']
# in 1 False
# 0 ['<Initials>EM</Initials>']
# in 1 False
# 0 ['</Author>']
# in 1 False
# 0 ['<Author ValidYN="Y">']
# in 1 False
# 0 ['<LastName>Deperas-Standylo</LastName>']
# in 1 False
# 0 ['<ForeName>Joanna</ForeName>']
# in 1 False
# 0 ['<Initials>J</Initials>']
# in 1 False
# 0 ['</Author>']
# in 1 False
# 0 ['<Author ValidYN="Y">']
# in 1 False
# 0 ['<LastName>Mitsyn</LastName>']
# in 1 False
# 0 ['<ForeName>Gennady V</ForeName>']
# in 1 False
# 0 ['<Initials>GV</Initials>']
# in 1 False
# 0 ['</Author>']
# in 1 False
# 0 ['<Author ValidYN="Y">']
# in 1 False
# 0 ['<LastName>Molokanov</LastName>']
# in 1 False
# 0 ['<ForeName>Alexander G</ForeName>']
# in 1 False
# 0 ['<Initials>AG</Initials>']
# in 1 False
# 0 ['</Author>']
# in 1 False
# 0 ['<Author ValidYN="Y">']
# in 1 False
# 0 ['<LastName>Timoshenko</LastName>']
# in 1 False
# 0 ['<ForeName>Gennady N</ForeName>']
# in 1 False
# 0 ['<Initials>GN</Initials>']
# in 1 False
# 0 ['</Author>']
# in 1 False
# 0 ['<Author ValidYN="Y">']
# in 1 False
# 0 ['<LastName>Wojcik</LastName>']
# in 1 False
# 0 ['<ForeName>Andrzej</ForeName>']
# in 1 False
# 0 ['<Initials>A</Initials>']
# in 1 False
# 0 ['</Author>']
# in 1 False
# 0 ['</AuthorList>']
# in 1 False
# 0 ['<Language>eng</Language>']
# in 1 False
# 0 ['<PublicationTypeList>']
# in 1 False
# 0 ['<PublicationType UI="D016428">Journal Article</PublicationType>']
# in 1 False
# 0 ['</PublicationTypeList>']
# in 1 False
# 0 ['<ArticleDate DateType="Electronic">']
# in 1 False
# 0 ['<Year>2010</Year>']
# in 1 False
# 0 ['<Month>07</Month>']
# in 1 False
# 0 ['<Day>29</Day>']
# in 1 False
# 0 ['</ArticleDate>']
# in 1 False
# 0 ['</Article>']
# in 1 False
# 0 ['<MedlineJournalInfo>']
# in 1 False
# 0 ['<Country>England</Country>']
# in 1 False
# 0 ['<MedlineTA>Int J Radiat Biol</MedlineTA>']
# in 1 False
# 0 ['<NlmUniqueID>8809243</NlmUniqueID>']
# in 1 False
# 0 ['<ISSNLinking>0955-3002</ISSNLinking>']
# in 1 False
# 0 ['</MedlineJournalInfo>']
# in 1 False
# 0 ['<CitationSubset>IM</CitationSubset>']
# in 1 False
# 0 ['<CitationSubset>S</CitationSubset>']
# in 1 False
# 0 ['<MeshHeadingList>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D000328" MajorTopicYN="N">Adult</DescriptorName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D002869" MajorTopicYN="N">Chromosome Aberrations</DescriptorName>']
# in 1 False
# 0 ['<QualifierName UI="Q000528" MajorTopicYN="Y">radiation effects</QualifierName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D002877" MajorTopicYN="N">Chromosomes, Human</DescriptorName>']
# in 1 False
# 0 ['<QualifierName UI="Q000235" MajorTopicYN="N">genetics</QualifierName>']
# in 1 False
# 0 ['<QualifierName UI="Q000378" MajorTopicYN="N">metabolism</QualifierName>']
# in 1 False
# 0 ['<QualifierName UI="Q000528" MajorTopicYN="Y">radiation effects</QualifierName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D004307" MajorTopicYN="N">Dose-Response Relationship, Radiation</DescriptorName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D005260" MajorTopicYN="N">Female</DescriptorName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D063193" MajorTopicYN="N">Heavy Ion Radiotherapy</DescriptorName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D020450" MajorTopicYN="N">Heavy Ions</DescriptorName>']
# in 1 False
# 0 ['<QualifierName UI="Q000009" MajorTopicYN="Y">adverse effects</QualifierName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D006801" MajorTopicYN="N">Humans</DescriptorName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D017404" MajorTopicYN="N">In Situ Hybridization, Fluorescence</DescriptorName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D018499" MajorTopicYN="Y">Linear Energy Transfer</DescriptorName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D008214" MajorTopicYN="N">Lymphocytes</DescriptorName>']
# in 1 False
# 0 ['<QualifierName UI="Q000378" MajorTopicYN="N">metabolism</QualifierName>']
# in 1 False
# 0 ['<QualifierName UI="Q000473" MajorTopicYN="N">pathology</QualifierName>']
# in 1 False
# 0 ['<QualifierName UI="Q000528" MajorTopicYN="Y">radiation effects</QualifierName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D008297" MajorTopicYN="N">Male</DescriptorName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D011836" MajorTopicYN="N">Radiation Tolerance</DescriptorName>']
# in 1 False
# 0 ['<QualifierName UI="Q000235" MajorTopicYN="N">genetics</QualifierName>']
# in 1 False
# 0 ['<QualifierName UI="Q000502" MajorTopicYN="N">physiology</QualifierName>']
# in 1 False
# 0 ['<QualifierName UI="Q000528" MajorTopicYN="Y">radiation effects</QualifierName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['<MeshHeading>']
# in 1 False
# 0 ['<DescriptorName UI="D013997" MajorTopicYN="N">Time Factors</DescriptorName>']
# in 1 False
# 0 ['</MeshHeading>']
# in 1 False
# 0 ['</MeshHeadingList>']
# in 1 False
# 0 ['</MedlineCitation>']
# in 1 False
# 0 ['<PubmedData>']
# in 1 False
# 0 ['<History>']
# in 1 False
# 0 ['<PubMedPubDate PubStatus="entrez">']
# in 1 False
# 0 ['<Year>2010</Year>']
# in 1 False
# 0 ['<Month>7</Month>']
# in 1 False
# 0 ['<Day>31</Day>']
# in 1 False
# 0 ['<Hour>6</Hour>']
# in 1 False
# 0 ['<Minute>0</Minute>']
# in 1 False
# 0 ['</PubMedPubDate>']
# in 1 False
# 0 ['<PubMedPubDate PubStatus="pubmed">']
# in 1 False
# 0 ['<Year>2010</Year>']
# in 1 False
# 0 ['<Month>7</Month>']
# in 1 False
# 0 ['<Day>31</Day>']
# in 1 False
# 0 ['<Hour>6</Hour>']
# in 1 False
# 0 ['<Minute>0</Minute>']
# in 1 False
# 0 ['</PubMedPubDate>']
# in 1 False
# 0 ['<PubMedPubDate PubStatus="medline">']
# in 1 False
# 0 ['<Year>2010</Year>']
# in 1 False
# 0 ['<Month>12</Month>']
# in 1 False
# 0 ['<Day>14</Day>']
# in 1 False
# 0 ['<Hour>6</Hour>']
# in 1 False
# 0 ['<Minute>0</Minute>']
# in 1 False
# 0 ['</PubMedPubDate>']
# in 1 False
# 0 ['</History>']
# in 1 False
# 0 ['<PublicationStatus>ppublish</PublicationStatus>']
# in 1 False
# 0 ['<ArticleIdList>']
# in 1 False
# 0 ['<ArticleId IdType="pubmed">20670111</ArticleId>']
# in 1 False
# 0 ['<ArticleId IdType="doi">10.3109/09553002.2010.496028</ArticleId>']
# in 1 False
# 0 ['</ArticleIdList>']
# in 1 False
# 0 ['</PubmedData>']
# in 1 False
# 0 ['</PubmedArticle>']
# in 1 False
#   # articles: 5

# %%
for i in pubmed_d:
    print(i)
    print(pubmed_d[i])
# Out:
# 20670107
# []
# 21480769
# []
# 20670108
# []
# 20670109
# []
# 20670110
# []
# 20670111
# []

# %% [markdown]
# ## Parsing NCBI taxonomy dmp files
#
# Assumptions about a plant science article:
# * Journal name contains any of the following:
#   * plant, plants, botany, botanical
# * Or title/abstract mentioned any plant taxonomic terms all the way to the genus level.

# %% [markdown]
# ### Taxonomy name file
# names.dmp
# * tax_id: id of node
# * name_txt: name itself
# * unique name: unique variant of this name
# * name class: synonym, common name etc.

# %%
# The following function:
# 1. Gets the tax_id of Viridiplantae.
# 2. Creates a dictionary name_dic with:
#   {tax_id:{name_class:[names]}
def get_name_dict(names_dmp_file):
    target    = "Viridiplantae"
    target_id = ""
    names_dmp = open(wd / "taxonomy" / names_dmp_file)
    L         = names_dmp.readline()
    names_dic = {}
    while L != "":
        L = L.strip().split("\t")
        tax_id = L[0]
        name   = L[2]
        name_c = L[6]
        if L[2] == "Viridiplantae":
            print("Viridiplantae tax_id:",tax_id)
            target_id = tax_id

        if tax_id not in names_dic:
            names_dic[tax_id] = {name_c:[name]}
        elif name_c not in names_dic[tax_id]:
            names_dic[tax_id][name_c] = [name]
        else:
            names_dic[tax_id][name_c].append(name)
        L = names_dmp.readline()
    return target_id, names_dic

# %%
target_id, names_dic = get_name_dict("test_name.dmp")
# Out:
# Viridiplantae tax_id: 33090

# %%
for i in names_dic:
    print("\n",i)
    print(names_dic[i])
# Out:
#  33083
# {'blast name': ['cellular slime molds'], 'scientific name': ['Dictyostelia'], 'synonym': ['Dictyostelida', 'Dictyostelids', 'Dictyosteliida'], 'genbank common name': ['dictyostelid cellular slime molds']}
#
#  33084
# {'authority': ['Entamoebidae Chatton 1925'], 'scientific name': ['Entamoebidae'], 'synonym': ['Entamoebida']}
#
#  33085
# {'authority': ['Entamoeba invadens Rodhaim, 1934'], 'scientific name': ['Entamoeba invadens']}
#
#  33090
# {'authority': ['Chlorobionta Jeffrey, 1982', 'Chloroplastida Adl et al. 2005', 'Viridiplantae Cavalier-Smith, 1981'], 'synonym': ['Chlorobionta', 'Chloroplastida'], 'equivalent name': ['Chlorophyta/Embryophyta group', 'chlorophyte/embryophyte group'], 'blast name': ['green plants'], 'common name': ['green plants'], 'scientific name': ['Viridiplantae']}
#
#  33091
# {'authority': ['Raphidonema Lagerheim, 1892'], 'scientific name': ['Raphidonema']}
#
#  33092
# {'scientific name': ['Koliella longiseta'], 'authority': ['Koliella longiseta (Vischer) Hindak, 1963', 'Raphidonema longiseta Vischer, 1933'], 'synonym': ['Raphidonema longiseta'], 'type material': ['SAG 470-1']}
#
#  33093
# {'authority': ['Chaetophoraceae Greville, 1824'], 'scientific name': ['Chaetophoraceae']}
#
#  33094
# {'authority': ['Draparnaldia Bory de Saint-Vincent, 1808'], 'scientific name': ['Draparnaldia']}
#
#  33095
# {'scientific name': ['Draparnaldia plumosa'], 'authority': ['Draparnaldia plumosa (Vaucher) C.Agardh']}
#
#  33096
# {'authority': ['Gonium O.F.Mueller, 1773'], 'scientific name': ['Gonium']}
#
#  33097
# {'authority': ['Gonium pectorale O.F.Mueller'], 'scientific name': ['Gonium pectorale']}
#
#  33098
# {'authority': ['Pandorina Bory de Saint-Vincent, 1824'], 'scientific name': ['Pandorina']}
#
#  33099
# {'authority': ['Pandorina morum (O.F.Mueller) Bory de Saint-Vincent'], 'scientific name': ['Pandorina morum']}
#
#  33100
# {'authority': ['Cosmarium Corda ex Ralfs, 1848'], 'scientific name': ['Cosmarium']}
#
#  33101
# {'authority': ['Cosmarium botrytis Meneghini ex Ralfs'], 'scientific name': ['Cosmarium botrytis']}
#
#  33102
# {'scientific name': ['Tetraselmis sp. RG-07']}
#
#  33103
# {'authority': ['Ulvophyceae Mattox and Stewart, 1984'], 'scientific name': ['Ulvophyceae']}
#
#  33104
# {'authority': ['Bryopsidales J.H.Schaffner, 1922'], 'scientific name': ['Bryopsidales'], 'synonym': ['Caulerpales']}
#
#  33105
# {'authority': ['Derbesiaceae Hauck, 1884'], 'scientific name': ['Derbesiaceae']}
#
#  33106
# {'scientific name': ['Derbesia'], 'authority': ['Derbesia Solier, 1846']}
#
#  33107
# {'authority': ['Derbesia marina (Lyngbye) Solier'], 'scientific name': ['Derbesia marina']}
#
#  33108
# {'authority': ['Calamovilfa longifolia (Hook.) Hack. ex Scribn. & Southw.'], 'synonym': ['Calamovilfa longifolia'], 'scientific name': ['Sporobolus rigidus']}
#
#  33109
# {'authority': ['Panicum capillare L.'], 'scientific name': ['Panicum capillare'], 'genbank common name': ['witchgrass']}

# %%
# Construct the full dictionary
target_id, names_dic = get_name_dict("names.dmp")
# Out:
# Viridiplantae tax_id: 33090

# %% [markdown]
# ### Taxonomy node file
#
# nodes.dmp file consists of taxonomy nodes. The description for each node includes the following columns:
# * tax_id -- node id in GenBank taxonomy database
# * parent tax_id -- parent node id in GenBank taxonomy database
# * rank -- rank of this node (superkingdom, kingdom, ...)
# * embl code -- locus-name prefix; not unique
# * division id -- see division.dmp file
# * inherited div flag (1 or 0) -- 1 if node inherits division from parent
# * genetic code id -- see gencode.dmp file
# * inherited GC flag (1 or 0) -- 1 if node inherits genetic code from parent
# * mitochondrial genetic code id -- see gencode.dmp file
# * inherited MGC flag (1 or 0) -- 1 if node inherits mitochondrial gencode from parent
# * GenBank hidden flag (1 or 0) -- 1 if name is suppressed in GenBank entry lineage
# * hidden subtree root flag (1 or 0) -- 1 if this subtree has no sequence data yet
# * comments-- free-text comments and citations

# %%
nodes_dmp_file = "nodes.dmp"

nodes_dmp   = open(wd / "taxonomy" / nodes_dmp_file)
L           = nodes_dmp.readline()
rank_d      = {}
paren_child = {}
child_paren = {}
while L != "":
    L = L.strip().split("\t")
    tax_id = L[0]
    par_id = L[2]
    rank   = L[4]
    if rank not in rank_d:
        rank_d[rank] = 1
    else:
        rank_d[rank]+= 1
    
    # Don't want any species or taxon with no rank
    if rank not in ["no rank", "species"]:
        if par_id not in paren_child:
            paren_child[par_id] = [tax_id]
        else:
            paren_child[par_id].append(tax_id)
        if tax_id not in child_paren:
            child_paren[tax_id] = par_id
        else:
            print(f"ERR: {tax_id} with >1 parents",
                  child_paren[tax_id], par_id)
        
    L = nodes_dmp.readline()

# %%
c = 0
for p in paren_child:
    print(p, paren_child[p])
    c += 1
    if c == 10:
        break
# Out:
# 131567 ['2', '2157', '2759']
# 335928 ['6', '99', '279', '152053', '204476', '556257']
# 1706371 ['10', '2425', '62100', '316625', '359337', '447467', '745153', '940550', '1050833', '1122283', '1122284', '1458243', '1792291', '1930860', '2036021', '2038244', '2752545']
# 203488 ['13']
# 32011 ['16', '404', '81682', '359407', '1679002', '2137425', '2676063', '2872156']
# 213421 ['18', '890', '37817', '57039']
# 76892 ['20', '75', '41275', '76890', '267929', '2052989', '2768684']
# 267890 ['22', '1573826', '2547964']
# 28221 ['29', '69541', '213113', '213115', '213118', '213462', '453227', '1779134', '2597219', '2814222', '2819262', '2844874', '2844876']
# 80811 ['31', '39', '1524213', '1524215']

# %%
def get_children(p, paren_child, child_list):
    print(p)
    if p in paren_child:
        # Initialize c with an empty element for debugging purpose
        c = [""]
        c = paren_child[p]
        print("",c)
        
        child_list.extend(c)
        for a_c in c:
            get_children(a_c, paren_child, child_list)
    else:
        print(" NO CHILD")
    return child_list

# %%
test_id1 = "980083" # Camelineae
paren_child[test_id1]
# Out:
# ['3701',
#  '3718',
#  '71323',
#  '98022',
#  '98032',
#  '106772',
#  '165360',
#  '264404',
#  '359815']

# %%
child_list = get_children(test_id1, paren_child, [])
# Out:
# 980083
#  ['3701', '3718', '71323', '98022', '98032', '106772', '165360', '264404', '359815']
# 3701
#  NO CHILD
# 3718
#  NO CHILD
# 71323
#  NO CHILD
# 98022
#  NO CHILD
# 98032
#  NO CHILD
# 106772
#  NO CHILD
# 165360
#  NO CHILD
# 264404
#  NO CHILD
# 359815
#  NO CHILD

# %%
child_list
# Out:
# ['3701',
#  '3718',
#  '71323',
#  '98022',
#  '98032',
#  '106772',
#  '165360',
#  '264404',
#  '359815']

# %%
test_id2 = "3700" # Brassicaceae
paren_child[test_id2]
# Out:
# ['947472',
#  '947473',
#  '947474',
#  '947475',
#  '947476',
#  '947477',
#  '947488',
#  '947489',
#  '947490',
#  '947491',
#  '947492',
#  '980082',
#  '980083',
#  '980085',
#  '980086',
#  '980115',
#  '980193',
#  '981066',
#  '981067',
#  '981068',
#  '981069',
#  '981070',
#  '981071',
#  '981096',
#  '981097',
#  '981098',
#  '981099',
#  '981100',
#  '981105',
#  '981107',
#  '981119',
#  '981120',
#  '981121',
#  '1248466',
#  '1394035',
#  '1394062',
#  '1394172',
#  '1394177',
#  '1394190',
#  '1394316',
#  '1394318',
#  '1394505',
#  '1394509',
#  '1394514',
#  '1394515',
#  '1394713',
#  '1394714',
#  '1394715',
#  '1394716',
#  '1394717',
#  '1394721',
#  '1520941',
#  '1920184']

# %%
child_list2 = get_children(test_id2, paren_child, [])
# Out:
# 3700
#  ['947472', '947473', '947474', '947475', '947476', '947477', '947488', '947489', '947490', '947491', '947492', '980082', '980083', '980085', '980086', '980115', '980193', '981066', '981067', '981068', '981069', '981070', '981071', '981096', '981097', '981098', '981099', '981100', '981105', '981107', '981119', '981120', '981121', '1248466', '1394035', '1394062', '1394172', '1394177', '1394190', '1394316', '1394318', '1394505', '1394509', '1394514', '1394515', '1394713', '1394714', '1394715', '1394716', '1394717', '1394721', '1520941', '1920184']
# 947472
#  ['264421', '282586', '282598', '2742424']
# 264421
#  NO CHILD
# 282586
#  NO CHILD
# 282598
#  NO CHILD
# 2742424
#  NO CHILD
# 947473
#  NO CHILD
# 947474
#  ['358660']
# 358660
#  NO CHILD
# 947475
#  ['3723', '359895', '368980', '369005', '369021', '369049', '369053', '682715', '743981', '1394143']
# 3723
#  NO CHILD
# 359895
#  NO CHILD
# 368980
#  NO CHILD
# 369005
#  NO CHILD
# 369021
#  NO CHILD
# 369049
#  NO CHILD
# 369053
#  NO CHILD
# 682715
#  NO CHILD
# 743981
#  NO CHILD
# 1394143
#  NO CHILD
# 947476
#  ['238894', '281479', '359839', '537171', '537177', '743986']
# 238894
#  NO CHILD
# 281479
#  NO CHILD
# 359839
#  NO CHILD
# 537171
#  NO CHILD
# 537177
#  NO CHILD
# 743986
#  NO CHILD
# 947477
#  ['97987', '97997', '98018', '253185', '264430', '282601', '345536', '358675', '359830', '359837', '359882', '359887', '359891', '368993', '369008', '375373', '537122', '537193', '663976', '664014', '664030', '664067', '664875', '763958', '763972', '763983', '1898703', '2259809', '2259828', '2259829']
# 97987
#  NO CHILD
# 97997
#  NO CHILD
# 98018
#  NO CHILD
# 253185
#  NO CHILD
# 264430
#  NO CHILD
# 282601
#  NO CHILD
# 345536
#  NO CHILD
# 358675
#  NO CHILD
# 359830
#  NO CHILD
# 359837
#  NO CHILD
# 359882
#  NO CHILD
# 359887
#  NO CHILD
# 359891
#  NO CHILD
# 368993
#  NO CHILD
# 369008
#  NO CHILD
# 375373
#  NO CHILD
# 537122
#  NO CHILD
# 537193
#  NO CHILD
# 663976
#  NO CHILD
# 664014
#  NO CHILD
# 664030
#  NO CHILD
# 664067
#  NO CHILD
# 664875
#  NO CHILD
# 763958
#  NO CHILD
# 763972
#  NO CHILD
# 763983
#  NO CHILD
# 1898703
#  NO CHILD
# 2259809
#  NO CHILD
# 2259828
#  NO CHILD
# 2259829
#  NO CHILD
# 947488
#  ['347878', '347894']
# 347878
#  NO CHILD
# 347894
#  NO CHILD
# 947489
#  ['153658', '264408', '264426', '537174', '664051']
# 153658
#  NO CHILD
# 264408
#  NO CHILD
# 264426
#  NO CHILD
# 537174
#  NO CHILD
# 664051
#  NO CHILD
# 947490
#  ['71282', '359845', '537183', '1394315']
# 71282
#  NO CHILD
# 359845
#  NO CHILD
# 537183
#  NO CHILD
# 1394315
#  NO CHILD
# 947491
#  ['228875', '369055']
# 228875
#  NO CHILD
# 369055
#  NO CHILD
# 947492
#  ['65352', '358671']
# 65352
#  NO CHILD
# 358671
#  NO CHILD
# 980082
#  ['72656', '359864']
# 72656
#  NO CHILD
# 359864
#  NO CHILD
# 980083
#  ['3701', '3718', '71323', '98022', '98032', '106772', '165360', '264404', '359815']
# 3701
#  NO CHILD
# 3718
#  NO CHILD
# 71323
#  NO CHILD
# 98022
#  NO CHILD
# 98032
#  NO CHILD
# 106772
#  NO CHILD
# 165360
#  NO CHILD
# 264404
#  NO CHILD
# 359815
#  NO CHILD
# 980085
#  ['76872', '95371', '115932', '359813', '359875', '359889', '374103', '500439', '2742425']
# 76872
#  NO CHILD
# 95371
#  NO CHILD
# 115932
#  NO CHILD
# 359813
#  NO CHILD
# 359875
#  NO CHILD
# 359889
#  NO CHILD
# 374103
#  NO CHILD
# 500439
#  NO CHILD
# 2742425
#  NO CHILD
# 980086
#  ['81986', '86710', '167687', '167692', '445675', '1394719']
# 81986
#  NO CHILD
# 86710
#  NO CHILD
# 167687
#  NO CHILD
# 167692
#  NO CHILD
# 445675
#  NO CHILD
# 1394719
#  NO CHILD
# 980115
#  ['86708', '97999', '98001', '98016', '98028', '98036', '303230']
# 86708
#  NO CHILD
# 97999
#  NO CHILD
# 98001
#  NO CHILD
# 98016
#  NO CHILD
# 98028
#  NO CHILD
# 98036
#  NO CHILD
# 303230
#  NO CHILD
# 980193
#  ['3703', '50457', '50460', '50495', '65947', '65949', '70804', '106778', '270111', '359855', '359878', '664035', '664059', '763950']
# 3703
#  NO CHILD
# 50457
#  NO CHILD
# 50460
#  NO CHILD
# 50495
#  NO CHILD
# 65947
#  NO CHILD
# 65949
#  NO CHILD
# 70804
#  NO CHILD
# 106778
#  NO CHILD
# 270111
#  NO CHILD
# 359855
#  NO CHILD
# 359878
#  NO CHILD
# 664035
#  NO CHILD
# 664059
#  NO CHILD
# 763950
#  NO CHILD
# 981066
#  ['19205', '264423', '396800', '537126', '547039', '664017', '763960', '763962']
# 19205
#  NO CHILD
# 264423
#  NO CHILD
# 396800
#  NO CHILD
# 537126
#  NO CHILD
# 547039
#  NO CHILD
# 664017
#  NO CHILD
# 763960
#  NO CHILD
# 763962
#  NO CHILD
# 981067
#  ['169067', '169390', '228873', '358663', '358667', '457760', '457782', '457787', '457789', '457801', '457805', '457819', '691205', '692718', '763661', '763979', '1187150', '1366902', '2282298', '2282313', '2282315', '2282316', '2282320', '2282322', '2282323', '2282324', '2282326']
# 169067
#  NO CHILD
# 169390
#  NO CHILD
# 228873
#  NO CHILD
# 358663
#  NO CHILD
# 358667
#  NO CHILD
# 457760
#  NO CHILD
# 457782
#  NO CHILD
# 457787
#  NO CHILD
# 457789
#  NO CHILD
# 457801
#  NO CHILD
# 457805
#  NO CHILD
# 457819
#  NO CHILD
# 691205
#  NO CHILD
# 692718
#  NO CHILD
# 763661
#  NO CHILD
# 763979
#  NO CHILD
# 1187150
#  NO CHILD
# 1366902
#  NO CHILD
# 2282298
#  NO CHILD
# 2282313
#  NO CHILD
# 2282315
#  NO CHILD
# 2282316
#  NO CHILD
# 2282320
#  NO CHILD
# 2282322
#  NO CHILD
# 2282323
#  NO CHILD
# 2282324
#  NO CHILD
# 2282326
#  NO CHILD
# 981068
#  ['89410', '98011', '153320', '153322', '153457', '270113', '578856']
# 89410
#  NO CHILD
# 98011
#  NO CHILD
# 153320
#  NO CHILD
# 153322
#  NO CHILD
# 153457
#  NO CHILD
# 270113
#  NO CHILD
# 578856
#  NO CHILD
# 981069
#  ['98034', '225680']
# 98034
#  NO CHILD
# 225680
#  NO CHILD
# 981070
#  ['50451', '81983', '87301', '161949', '169071', '358649', '359819', '457779', '457785', '663966', '743930', '1282140', '1394152', '1394159', '1394168', '1394169', '1394170']
# 50451
#  NO CHILD
# 81983
#  NO CHILD
# 87301
#  NO CHILD
# 161949
#  NO CHILD
# 169071
#  NO CHILD
# 358649
#  NO CHILD
# 359819
#  NO CHILD
# 457779
#  NO CHILD
# 457785
#  NO CHILD
# 663966
#  NO CHILD
# 743930
#  NO CHILD
# 1282140
#  NO CHILD
# 1394152
#  NO CHILD
# 1394159
#  NO CHILD
# 1394168
#  NO CHILD
# 1394169
#  NO CHILD
# 1394170
#  NO CHILD
# 981071
#  ['3705', '3720', '3725', '3727', '3731', '19151', '55964', '56475', '71233', '71347', '71349', '71351', '71353', '71355', '71357', '71359', '71361', '71363', '109153', '127602', '127606', '127608', '127610', '127614', '127616', '127625', '180539', '220482', '308268', '308272', '308286', '308299', '308301', '308303', '308306', '308312', '308316', '418794', '663962', '663982', '663995', '663999', '664008', '664025', '665106', '763966', '763970', '763981', '1920186', '2696042']
# 3705
#  NO CHILD
# 3720
#  NO CHILD
# 3725
#  NO CHILD
# 3727
#  NO CHILD
# 3731
#  NO CHILD
# 19151
#  NO CHILD
# 55964
#  NO CHILD
# 56475
#  NO CHILD
# 71233
#  NO CHILD
# 71347
#  NO CHILD
# 71349
#  NO CHILD
# 71351
#  NO CHILD
# 71353
#  NO CHILD
# 71355
#  NO CHILD
# 71357
#  NO CHILD
# 71359
#  NO CHILD
# 71361
#  NO CHILD
# 71363
#  NO CHILD
# 109153
#  NO CHILD
# 127602
#  NO CHILD
# 127606
#  NO CHILD
# 127608
#  NO CHILD
# 127610
#  NO CHILD
# 127614
#  NO CHILD
# 127616
#  NO CHILD
# 127625
#  NO CHILD
# 180539
#  NO CHILD
# 220482
#  NO CHILD
# 308268
#  NO CHILD
# 308272
#  NO CHILD
# 308286
#  NO CHILD
# 308299
#  NO CHILD
# 308301
#  NO CHILD
# 308303
#  NO CHILD
# 308306
#  NO CHILD
# 308312
#  NO CHILD
# 308316
#  NO CHILD
# 418794
#  NO CHILD
# 663962
#  NO CHILD
# 663982
#  NO CHILD
# 663995
#  NO CHILD
# 663999
#  NO CHILD
# 664008
#  NO CHILD
# 664025
#  NO CHILD
# 665106
#  NO CHILD
# 763966
#  NO CHILD
# 763970
#  NO CHILD
# 763981
#  NO CHILD
# 1920186
#  NO CHILD
# 2696042
#  NO CHILD
# 981096
#  ['154095', '203597', '203611', '359885', '369016', '536416', '2742416']
# 154095
#  NO CHILD
# 203597
#  NO CHILD
# 203611
#  NO CHILD
# 359885
#  NO CHILD
# 369016
#  NO CHILD
# 536416
#  NO CHILD
# 2742416
#  NO CHILD
# 981097
#  ['3729', '115936', '664019']
# 3729
#  NO CHILD
# 115936
#  NO CHILD
# 664019
#  NO CHILD
# 981098
#  ['161755', '358658', '358673', '359866', '651648', '651651', '663978', '664002', '664057']
# 161755
#  NO CHILD
# 358658
#  NO CHILD
# 358673
#  NO CHILD
# 359866
#  NO CHILD
# 651648
#  NO CHILD
# 651651
#  NO CHILD
# 663978
#  NO CHILD
# 664002
#  NO CHILD
# 664057
#  NO CHILD
# 981099
#  ['13287', '126269', '138178', '138180', '138182', '359880', '359905', '359909', '457794', '663990', '664041', '664048', '664063', '2497495', '2558168', '2558169']
# 13287
#  NO CHILD
# 126269
#  NO CHILD
# 138178
#  NO CHILD
# 138180
#  NO CHILD
# 138182
#  NO CHILD
# 359880
#  NO CHILD
# 359905
#  NO CHILD
# 359909
#  NO CHILD
# 457794
#  NO CHILD
# 663990
#  NO CHILD
# 664041
#  NO CHILD
# 664048
#  NO CHILD
# 664063
#  NO CHILD
# 2497495
#  NO CHILD
# 2558168
#  NO CHILD
# 2558169
#  NO CHILD
# 981100
#  ['72663', '98005', '345530', '359828']
# 72663
#  NO CHILD
# 98005
#  NO CHILD
# 345530
#  NO CHILD
# 359828
#  NO CHILD
# 981105
#  NO CHILD
# 981107
#  ['264417', '763985']
# 264417
#  NO CHILD
# 763985
#  NO CHILD
# 981119
#  ['263652']
# 263652
#  NO CHILD
# 981120
#  ['97854', '104255']
# 97854
#  NO CHILD
# 104255
#  NO CHILD
# 981121
#  ['165362', '190883']
# 165362
#  NO CHILD
# 190883
#  NO CHILD
# 1248466
#  ['106787', '359893', '368986', '537138', '663974', '665080', '693859', '693861', '763975', '913018', '1221661', '1248443', '1248445', '1248447', '1248449', '1248452']
# 106787
#  NO CHILD
# 359893
#  NO CHILD
# 368986
#  NO CHILD
# 537138
#  NO CHILD
# 663974
#  NO CHILD
# 665080
#  NO CHILD
# 693859
#  NO CHILD
# 693861
#  NO CHILD
# 763975
#  NO CHILD
# 913018
#  NO CHILD
# 1221661
#  NO CHILD
# 1248443
#  NO CHILD
# 1248445
#  NO CHILD
# 1248447
#  NO CHILD
# 1248449
#  NO CHILD
# 1248452
#  NO CHILD
# 1394035
#  ['98024', '586511', '590623', '663985']
# 98024
#  NO CHILD
# 586511
#  NO CHILD
# 590623
#  NO CHILD
# 663985
#  NO CHILD
# 1394062
#  ['226050', '234453', '359841', '368990', '368995', '368997', '369014', '369023', '369027', '369031', '663964', '664012', '763968']
# 226050
#  NO CHILD
# 234453
#  NO CHILD
# 359841
#  NO CHILD
# 368990
#  NO CHILD
# 368995
#  NO CHILD
# 368997
#  NO CHILD
# 369014
#  NO CHILD
# 369023
#  NO CHILD
# 369027
#  NO CHILD
# 369031
#  NO CHILD
# 663964
#  NO CHILD
# 664012
#  NO CHILD
# 763968
#  NO CHILD
# 1394172
#  ['97985', '283748', '362821', '391729', '537188']
# 97985
#  NO CHILD
# 283748
#  NO CHILD
# 362821
#  NO CHILD
# 391729
#  NO CHILD
# 537188
#  NO CHILD
# 1394177
#  ['359558']
# 359558
#  NO CHILD
# 1394190
#  ['165354']
# 165354
#  NO CHILD
# 1394316
#  ['97990', '185690', '1394317']
# 97990
#  NO CHILD
# 185690
#  NO CHILD
# 1394317
#  NO CHILD
# 1394318
#  ['379571']
# 379571
#  NO CHILD
# 1394505
#  ['126277', '165384', '290573', '664871', '763947', '763954', '763956', '1394507', '1684427', '1979869', '1979871', '2497496', '2497507', '2497508', '2497540']
# 126277
#  NO CHILD
# 165384
#  NO CHILD
# 290573
#  NO CHILD
# 664871
#  NO CHILD
# 763947
#  NO CHILD
# 763954
#  NO CHILD
# 763956
#  NO CHILD
# 1394507
#  NO CHILD
# 1684427
#  NO CHILD
# 1979869
#  NO CHILD
# 1979871
#  NO CHILD
# 2497496
#  NO CHILD
# 2497507
#  NO CHILD
# 2497508
#  NO CHILD
# 2497540
#  NO CHILD
# 1394509
#  ['359834', '359862', '1914272', '2797270']
# 359834
#  NO CHILD
# 359862
#  NO CHILD
# 1914272
#  NO CHILD
# 2797270
#  NO CHILD
# 1394514
#  ['106784']
# 106784
#  NO CHILD
# 1394515
#  ['536376', '536394', '544820', '544831', '763987', '1394517', '2591846', '2591904']
# 536376
#  NO CHILD
# 536394
#  NO CHILD
# 544820
#  NO CHILD
# 544831
#  NO CHILD
# 763987
#  NO CHILD
# 1394517
#  NO CHILD
# 2591846
#  NO CHILD
# 2591904
#  NO CHILD
# 1394713
#  ['169073', '190888']
# 169073
#  NO CHILD
# 190888
#  NO CHILD
# 1394714
#  ['85227', '473979']
# 85227
#  NO CHILD
# 473979
#  NO CHILD
# 1394715
#  ['664023', '664033']
# 664023
#  NO CHILD
# 664033
#  NO CHILD
# 1394716
#  ['946225']
# 946225
#  NO CHILD
# 1394717
#  ['50330', '72661', '154103', '203600', '203604', '203607', '203614', '203619', '203623', '203625', '203630', '229020', '301455', '359868', '536378', '536383', '536386', '536388', '536392', '536398', '536408', '544822', '544833', '544835', '763977', '946222', '1394718', '1405534', '1930281', '2212455']
# 50330
#  NO CHILD
# 72661
#  NO CHILD
# 154103
#  NO CHILD
# 203600
#  NO CHILD
# 203604
#  NO CHILD
# 203607
#  NO CHILD
# 203614
#  NO CHILD
# 203619
#  NO CHILD
# 203623
#  NO CHILD
# 203625
#  NO CHILD
# 203630
#  NO CHILD
# 229020
#  NO CHILD
# 301455
#  NO CHILD
# 359868
#  NO CHILD
# 536378
#  NO CHILD
# 536383
#  NO CHILD
# 536386
#  NO CHILD
# 536388
#  NO CHILD
# 536392
#  NO CHILD
# 536398
#  NO CHILD
# 536408
#  NO CHILD
# 544822
#  NO CHILD
# 544833
#  NO CHILD
# 544835
#  NO CHILD
# 763977
#  NO CHILD
# 946222
#  NO CHILD
# 1394718
#  NO CHILD
# 1405534
#  NO CHILD
# 1930281
#  NO CHILD
# 2212455
#  NO CHILD
# 1394721
#  ['81990']
# 81990
#  NO CHILD
# 1520941
#  NO CHILD
# 1920184
#  ['97856']
# 97856
#  NO CHILD

# %%
child_list2
# Out:
# ['947472',
#  '947473',
#  '947474',
#  '947475',
#  '947476',
#  '947477',
#  '947488',
#  '947489',
#  '947490',
#  '947491',
#  '947492',
#  '980082',
#  '980083',
#  '980085',
#  '980086',
#  '980115',
#  '980193',
#  '981066',
#  '981067',
#  '981068',
#  '981069',
#  '981070',
#  '981071',
#  '981096',
#  '981097',
#  '981098',
#  '981099',
#  '981100',
#  '981105',
#  '981107',
#  '981119',
#  '981120',
#  '981121',
#  '1248466',
#  '1394035',
#  '1394062',
#  '1394172',
#  '1394177',
#  '1394190',
#  '1394316',
#  '1394318',
#  '1394505',
#  '1394509',
#  '1394514',
#  '1394515',
#  '1394713',
#  '1394714',
#  '1394715',
#  '1394716',
#  '1394717',
#  '1394721',
#  '1520941',
#  '1920184',
#  '264421',
#  '282586',
#  '282598',
#  '2742424',
#  '358660',
#  '3723',
#  '359895',
#  '368980',
#  '369005',
#  '369021',
#  '369049',
#  '369053',
#  '682715',
#  '743981',
#  '1394143',
#  '238894',
#  '281479',
#  '359839',
#  '537171',
#  '537177',
#  '743986',
#  '97987',
#  '97997',
#  '98018',
#  '253185',
#  '264430',
#  '282601',
#  '345536',
#  '358675',
#  '359830',
#  '359837',
#  '359882',
#  '359887',
#  '359891',
#  '368993',
#  '369008',
#  '375373',
#  '537122',
#  '537193',
#  '663976',
#  '664014',
#  '664030',
#  '664067',
#  '664875',
#  '763958',
#  '763972',
#  '763983',
#  '1898703',
#  '2259809',
#  '2259828',
#  '2259829',
#  '347878',
#  '347894',
#  '153658',
#  '264408',
#  '264426',
#  '537174',
#  '664051',
#  '71282',
#  '359845',
#  '537183',
#  '1394315',
#  '228875',
#  '369055',
#  '65352',
#  '358671',
#  '72656',
#  '359864',
#  '3701',
#  '3718',
#  '71323',
#  '98022',
#  '98032',
#  '106772',
#  '165360',
#  '264404',
#  '359815',
#  '76872',
#  '95371',
#  '115932',
#  '359813',
#  '359875',
#  '359889',
#  '374103',
#  '500439',
#  '2742425',
#  '81986',
#  '86710',
#  '167687',
#  '167692',
#  '445675',
#  '1394719',
#  '86708',
#  '97999',
#  '98001',
#  '98016',
#  '98028',
#  '98036',
#  '303230',
#  '3703',
#  '50457',
#  '50460',
#  '50495',
#  '65947',
#  '65949',
#  '70804',
#  '106778',
#  '270111',
#  '359855',
#  '359878',
#  '664035',
#  '664059',
#  '763950',
#  '19205',
#  '264423',
#  '396800',
#  '537126',
#  '547039',
#  '664017',
#  '763960',
#  '763962',
#  '169067',
#  '169390',
#  '228873',
#  '358663',
#  '358667',
#  '457760',
#  '457782',
#  '457787',
#  '457789',
#  '457801',
#  '457805',
#  '457819',
#  '691205',
#  '692718',
#  '763661',
#  '763979',
#  '1187150',
#  '1366902',
#  '2282298',
#  '2282313',
#  '2282315',
#  '2282316',
#  '2282320',
#  '2282322',
#  '2282323',
#  '2282324',
#  '2282326',
#  '89410',
#  '98011',
#  '153320',
#  '153322',
#  '153457',
#  '270113',
#  '578856',
#  '98034',
#  '225680',
#  '50451',
#  '81983',
#  '87301',
#  '161949',
#  '169071',
#  '358649',
#  '359819',
#  '457779',
#  '457785',
#  '663966',
#  '743930',
#  '1282140',
#  '1394152',
#  '1394159',
#  '1394168',
#  '1394169',
#  '1394170',
#  '3705',
#  '3720',
#  '3725',
#  '3727',
#  '3731',
#  '19151',
#  '55964',
#  '56475',
#  '71233',
#  '71347',
#  '71349',
#  '71351',
#  '71353',
#  '71355',
#  '71357',
#  '71359',
#  '71361',
#  '71363',
#  '109153',
#  '127602',
#  '127606',
#  '127608',
#  '127610',
#  '127614',
#  '127616',
#  '127625',
#  '180539',
#  '220482',
#  '308268',
#  '308272',
#  '308286',
#  '308299',
#  '308301',
#  '308303',
#  '308306',
#  '308312',
#  '308316',
#  '418794',
#  '663962',
#  '663982',
#  '663995',
#  '663999',
#  '664008',
#  '664025',
#  '665106',
#  '763966',
#  '763970',
#  '763981',
#  '1920186',
#  '2696042',
#  '154095',
#  '203597',
#  '203611',
#  '359885',
#  '369016',
#  '536416',
#  '2742416',
#  '3729',
#  '115936',
#  '664019',
#  '161755',
#  '358658',
#  '358673',
#  '359866',
#  '651648',
#  '651651',
#  '663978',
#  '664002',
#  '664057',
#  '13287',
#  '126269',
#  '138178',
#  '138180',
#  '138182',
#  '359880',
#  '359905',
#  '359909',
#  '457794',
#  '663990',
#  '664041',
#  '664048',
#  '664063',
#  '2497495',
#  '2558168',
#  '2558169',
#  '72663',
#  '98005',
#  '345530',
#  '359828',
#  '264417',
#  '763985',
#  '263652',
#  '97854',
#  '104255',
#  '165362',
#  '190883',
#  '106787',
#  '359893',
#  '368986',
#  '537138',
#  '663974',
#  '665080',
#  '693859',
#  '693861',
#  '763975',
#  '913018',
#  '1221661',
#  '1248443',
#  '1248445',
#  '1248447',
#  '1248449',
#  '1248452',
#  '98024',
#  '586511',
#  '590623',
#  '663985',
#  '226050',
#  '234453',
#  '359841',
#  '368990',
#  '368995',
#  '368997',
#  '369014',
#  '369023',
#  '369027',
#  '369031',
#  '663964',
#  '664012',
#  '763968',
#  '97985',
#  '283748',
#  '362821',
#  '391729',
#  '537188',
#  '359558',
#  '165354',
#  '97990',
#  '185690',
#  '1394317',
#  '379571',
#  '126277',
#  '165384',
#  '290573',
#  '664871',
#  '763947',
#  '763954',
#  '763956',
#  '1394507',
#  '1684427',
#  '1979869',
#  '1979871',
#  '2497496',
#  '2497507',
#  '2497508',
#  '2497540',
#  '359834',
#  '359862',
#  '1914272',
#  '2797270',
#  '106784',
#  '536376',
#  '536394',
#  '544820',
#  '544831',
#  '763987',
#  '1394517',
#  '2591846',
#  '2591904',
#  '169073',
#  '190888',
#  '85227',
#  '473979',
#  '664023',
#  '664033',
#  '946225',
#  '50330',
#  '72661',
#  '154103',
#  '203600',
#  '203604',
#  '203607',
#  '203614',
#  '203619',
#  '203623',
#  '203625',
#  '203630',
#  '229020',
#  '301455',
#  '359868',
#  '536378',
#  '536383',
#  '536386',
#  '536388',
#  '536392',
#  '536398',
#  '536408',
#  '544822',
#  '544833',
#  '544835',
#  '763977',
#  '946222',
#  '1394718',
#  '1405534',
#  '1930281',
#  '2212455',
#  '81990',
#  '97856']

# %% [markdown]
# ## Rid of HTML tags in title and abstract

# %%
def get_value(L):
    # Get the 1st chuck of text 
    tag1_L_b = L.find("<")  # beginning html tag, Left, beginning
    tag1_L_e = L.find(">")  # beginning html tag, Left, ending
    tag1_R_b = L.find("</") # beginning html tag, Right, beginning
    
    # Text example
    # L1           L2      L3
    # blah blah <i>bleh</i> and <d>blue</d>.
    L1 = L[:tag1_L_b]
    L2 = L[tag1_L_e+1 : tag1_R_b]
    L3 = L[tag1_R_b:]
    tag1_R_e = L3.find(">") # beginning html tag, Right, ending
    L3 = L3[tag1_R_e+1:]
    
    L = L1 + L2 + L3
    
    # Check if there is more tag, if so, run the function again
    if len(L.split("<")) > 1:
        L = get_value(L)
        
    return L

# %%
L = "<test>Test <idx>to</idx> see if <d>the function</d> works.</test>"

# %%
L = get_value(L)
L
# Out:
# 'Test to see if the function works.'

# %% [markdown]
# ## Token matching

# %% [markdown]
# ## Continue development
#
# * For the taxonomy keywords: script_get_plant_taxa.py
# * For getting only plant articles: script_parse_pubmed.py

# %%
AB = "Abstract"

# %%
f"<{AB}>" == "<Abstract>"
# Out:
# True
