# %% [markdown]
# # __Step 3.2: Clustering based on Tf-idf__
#
# The goals for step 3.2 are to:
# - Cluster docs so each clsuter representing a subfield of plant sciences

# %% [markdown]
# ## ___Set up___

# %% [markdown]
# ### Module import
#
# ```bash
# conda install -c conda-forge umap-learn
# conda install -c conda-forge hdbscan
# ```

# %%
import sys, os, pickle
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path
from tqdm import tqdm
from datetime import datetime
from scipy.sparse import csr_matrix

# Specify subspace-clustering module location
# The selfrerepsentation.py is modified so using tqdm instead of progressbar
module_selfrep = Path.home() / 'github/subspace-clustering/cluster'
sys.path.append(str(module_selfrep))
from selfrepresentation import ElasticNetSubspaceClustering

import umap
import hdbscan
from sklearn.manifold import TSNE
from sklearn.cluster import SpectralClustering, KMeans
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import normalize, StandardScaler
from sklearn.decomposition import TruncatedSVD
from keras.layers import Dense, Input
from keras.models import Model
from keras.models import load_model
from keras.callbacks import ModelCheckpoint

# %% [markdown]
# ### Key variables

# %%
# Reproducibility
seed = 20220609

# Setting working directory
proj_dir   = Path.home() / "projects/plant_sci_hist"
work_dir   = proj_dir / "3_key_term_temporal/3_2_tf_idf_clustering"
work_dir.mkdir(parents=True, exist_ok=True)

os.chdir(work_dir)

# science dictionary vocab directory
sci_dict_dir = proj_dir / "_vocab"

# specify plant science corpus
sparse_matrix_dir  = proj_dir / "3_key_term_temporal/3_1_pubmed_vocab"
sparse_matrix_file = sparse_matrix_dir / "tfidf_sparse_matrix_4542"
feat_name_file     = sparse_matrix_dir / "tfidf_feat_name_and_sum_4542"

# %% [markdown]
# ### Read sparse matrix and feature names

# %%
# Load sparse matrix from a pickle
with open(sparse_matrix_file, 'rb') as f:
  X_vec = pickle.load(f)

# Load feature names and tf-idf sum
feat_sum = pd.read_csv(feat_name_file, sep='\t')

X_vec.shape, feat_sum.shape
# Out:
# ((421658, 4542), (4542, 3))

# %% [markdown]
# ### Normalization
#
# [This](https://towardsdatascience.com/understand-data-normalization-in-machine-learning-8ff3062101f0) and [this](https://iq.opengenus.org/normalization-in-detail/) posts are helpful.

# %%
np.min(X_vec[:,1]), np.max(X_vec[:,1])
# Out:
# (0.0, 0.9355844320660135)

# %%
# Standardize each feature then convert to interger, so the memory requirement
# is not so bad. Cannot get the interger call to work, sill called as float32,
# but at least it is smaller.
X_vec_norm = StandardScaler(with_mean=False).fit_transform(X_vec).astype('float32')
type(X_vec_norm), X_vec_norm.shape
# Out:
# (scipy.sparse._csr.csr_matrix, (421658, 4542))

# %%
np.min(X_vec_norm[:,1]), np.max(X_vec_norm[:,1])
# Out:
# (0.0, 53.0883)

# %% [markdown]
# ### Dimensionality reduction
#
# Check out:
# - [What, Why and How of t-SNE](https://towardsdatascience.com/what-why-and-how-of-t-sne-1f78d13e224d)
# - [An Introduction to t-SNE with Python Example](https://towardsdatascience.com/an-introduction-to-t-sne-with-python-example-5a3a293108d1)
# - [TSNE Visualization Example in Python ](https://www.datatechnotes.com/2020/11/tsne-visualization-example-in-python.html)
# - [Introduction to t-SNE in Python with scikit-learn](https://danielmuellerkomorowska.com/2021/01/05/introduction-to-t-sne-in-python-with-scikit-learn/)
#
# Cannot run locally:
# - Move to HPC
# - Try [this advice](https://stackoverflow.com/questions/32105302/dimension-reduction-with-t-sne), do PCA first then do tSNE. But PCA does not support Sparse input. Use TruncatedSVD instead.
#   - Still need a lot of memory... don't understand why.
# - Don't do TSNE, Use the PCA matrix for clustering next.

# %%
svd = TruncatedSVD(n_components=100, n_iter=7, random_state=seed)
svd.fit(X_vec_norm)
# Out:
# TruncatedSVD(n_components=100, n_iter=7, random_state=20220609)

# %%
X_vec_norm_pca = csr_matrix(svd.transform(X_vec_norm))
X_vec_norm_pca.shape, type(X_vec_norm_pca)
# Out:
# ((421658, 100), scipy.sparse._csr.csr_matrix)

# %%
with open(work_dir / "X_vec_norm_pca", "wb") as f:
  pickle.dump(X_vec_norm_pca, f)

# %%
# Still won't work after dimensionality reduction. Make sure, still asked to
# build a 421658x421658 matrix to store pairwise info.
# Run in HPC using the full matrix

#model_tsne = TSNE(n_components=20, random_state=seed, perplexity=50,
#                  method='exact', n_iter=5000, verbose=2, n_jobs=16,
#                  init='random', learning_rate='auto')
#X_vec_norm_tsne = model_tsne.fit_transform(X_vec_norm_pca)
# Out:
# "\nmodel_tsne = TSNE(n_components=20, random_state=seed, perplexity=50,\n                  method='exact', n_iter=5000, verbose=2, n_jobs=16,\n                  init='random', learning_rate='auto')\nX_vec_norm_tsne = model_tsne.fit_transform(X_vec_norm_pca)\n"

# %% [markdown]
# ## ___Clustering___
#
# Check out:
# - [How to cluster in High Dimensions](https://towardsdatascience.com/how-to-cluster-in-high-dimensions-4ef693bacc6)

# %% [markdown]
# ### Kmeans

# %%
clus_kmeans = KMeans(n_clusters=500, random_state=seed, max_iter=400, verbose=3)

# %%
clus_kmeans.fit(X_vec_norm_pca)
# Out:
# Initialization complete
# Iteration 0, inertia 70938928.0.
# Iteration 1, inertia 54233964.0.
# Iteration 2, inertia 52660980.0.
# Iteration 3, inertia 52072628.0.
# Iteration 4, inertia 51767040.0.
# Iteration 5, inertia 51569404.0.
# Iteration 6, inertia 51419312.0.
# Iteration 7, inertia 51323668.0.
# Iteration 8, inertia 51258548.0.
# Iteration 9, inertia 51203852.0.
# Iteration 10, inertia 51152516.0.
# Iteration 11, inertia 51107504.0.
# Iteration 12, inertia 51068444.0.
# Iteration 13, inertia 51034852.0.
# Iteration 14, inertia 51007640.0.
# Iteration 15, inertia 50983460.0.
# Iteration 16, inertia 50960728.0.
# Iteration 17, inertia 50938448.0.
# Iteration 18, inertia 50919500.0.
# Iteration 19, inertia 50902460.0.
# Iteration 20, inertia 50887404.0.
# Iteration 21, inertia 50875092.0.
# Iteration 22, inertia 50865476.0.
# Iteration 23, inertia 50858040.0.
# Iteration 24, inertia 50851720.0.
# Iteration 25, inertia 50845236.0.
# Iteration 26, inertia 50838092.0.
# Iteration 27, inertia 50829612.0.
# Iteration 28, inertia 50821368.0.
# Iteration 29, inertia 50813092.0.
# Iteration 30, inertia 50805696.0.
# Iteration 31, inertia 50799784.0.
# Iteration 32, inertia 50794372.0.
# Iteration 33, inertia 50789540.0.
# Iteration 34, inertia 50785352.0.
# Iteration 35, inertia 50781568.0.
# Iteration 36, inertia 50777868.0.
# Iteration 37, inertia 50774480.0.
# Iteration 38, inertia 50771656.0.
# Iteration 39, inertia 50769144.0.
# Iteration 40, inertia 50766756.0.
# Iteration 41, inertia 50764360.0.
# Iteration 42, inertia 50761976.0.
# Iteration 43, inertia 50759688.0.
# Iteration 44, inertia 50757716.0.
# Iteration 45, inertia 50755828.0.
# Iteration 46, inertia 50754076.0.
# Iteration 47, inertia 50752392.0.
# Iteration 48, inertia 50750728.0.
# Iteration 49, inertia 50749108.0.
# Iteration 50, inertia 50747160.0.
# Iteration 51, inertia 50744804.0.
# Iteration 52, inertia 50742216.0.
# Iteration 53, inertia 50739812.0.
# Iteration 54, inertia 50737944.0.
# Iteration 55, inertia 50736620.0.
# Iteration 56, inertia 50735520.0.
# Iteration 57, inertia 50734652.0.
# Iteration 58, inertia 50733860.0.
# Iteration 59, inertia 50733120.0.
# Iteration 60, inertia 50732428.0.
# Iteration 61, inertia 50731628.0.
# Iteration 62, inertia 50730780.0.
# Iteration 63, inertia 50729848.0.
# Iteration 64, inertia 50728948.0.
# Iteration 65, inertia 50728056.0.
# Iteration 66, inertia 50727092.0.
# Iteration 67, inertia 50726264.0.
# Iteration 68, inertia 50725436.0.
# Iteration 69, inertia 50724632.0.
# Iteration 70, inertia 50723904.0.
# Iteration 71, inertia 50723180.0.
# Iteration 72, inertia 50722352.0.
# Iteration 73, inertia 50720956.0.
# Iteration 74, inertia 50717848.0.
# Iteration 75, inertia 50712816.0.
# Iteration 76, inertia 50709120.0.
# Iteration 77, inertia 50708020.0.
# Iteration 78, inertia 50707528.0.
# Iteration 79, inertia 50707140.0.
# Iteration 80, inertia 50706736.0.
# Iteration 81, inertia 50706372.0.
# Iteration 82, inertia 50706104.0.
# Iteration 83, inertia 50705868.0.
# Iteration 84, inertia 50705632.0.
# Iteration 85, inertia 50705408.0.
# Iteration 86, inertia 50705224.0.
# Iteration 87, inertia 50705104.0.
# Iteration 88, inertia 50704964.0.
# Iteration 89, inertia 50704884.0.
# Iteration 90, inertia 50704760.0.
# Iteration 91, inertia 50704692.0.
# Iteration 92, inertia 50704632.0.
# Iteration 93, inertia 50704544.0.
# Iteration 94, inertia 50704392.0.
# Iteration 95, inertia 50704288.0.
# Iteration 96, inertia 50704172.0.
# Iteration 97, inertia 50704084.0.
# Iteration 98, inertia 50704032.0.
# Iteration 99, inertia 50703952.0.
# Iteration 100, inertia 50703932.0.
# Iteration 101, inertia 50703880.0.
# Iteration 102, inertia 50703864.0.
# Iteration 103, inertia 50703824.0.
# Iteration 104, inertia 50703788.0.
# Iteration 105, inertia 50703776.0.
# Iteration 106, inertia 50703768.0.
# Iteration 107, inertia 50703704.0.
# Iteration 108, inertia 50703720.0.
# Iteration 109, inertia 50703676.0.
# Iteration 110, inertia 50703656.0.
# Iteration 111, inertia 50703632.0.
# Iteration 112, inertia 50703540.0.
# Iteration 198, inertia 50704036.0.
# Iteration 199, inertia 50704020.0.
# Iteration 200, inertia 50704008.0.
# Iteration 201, inertia 50703984.0.
# Iteration 202, inertia 50703944.0.
# Iteration 203, inertia 50703928.0.
# Iteration 204, inertia 50703888.0.
# Iteration 205, inertia 50703880.0.
# Iteration 206, inertia 50703860.0.
# Iteration 207, inertia 50703852.0.
# Iteration 208, inertia 50703832.0.
# Iteration 209, inertia 50703828.0.
# Iteration 210, inertia 50703800.0.
# Iteration 211, inertia 50703780.0.
# Iteration 212, inertia 50703780.0.
# Iteration 213, inertia 50703752.0.
# Iteration 214, inertia 50703752.0.
# Iteration 215, inertia 50703760.0.
# Iteration 216, inertia 50703748.0.
# Iteration 217, inertia 50703744.0.
# Iteration 218, inertia 50703736.0.
# Iteration 219, inertia 50703736.0.
# Iteration 220, inertia 50703736.0.
# Iteration 221, inertia 50703724.0.
# Iteration 222, inertia 50703728.0.
# Iteration 223, inertia 50703744.0.
# Iteration 224, inertia 50703732.0.
# Iteration 225, inertia 50703732.0.
# Iteration 226, inertia 50703720.0.
# Iteration 227, inertia 50703712.0.
# Iteration 228, inertia 50703716.0.
# Iteration 229, inertia 50703704.0.
# Iteration 230, inertia 50703696.0.
# Iteration 231, inertia 50703700.0.
# Iteration 232, inertia 50703700.0.
# Iteration 233, inertia 50703724.0.
# Iteration 234, inertia 50703724.0.
# Iteration 235, inertia 50703728.0.
# Iteration 236, inertia 50703720.0.
# Converged at iteration 236: center shift 0.00031238686642609537 within tolerance 0.0003486533403396607.
# Initialization complete
# Iteration 0, inertia 70649168.0.
# Iteration 1, inertia 54023968.0.
# Iteration 2, inertia 52519828.0.
# Iteration 3, inertia 51980672.0.
# Iteration 4, inertia 51697896.0.
# Iteration 5, inertia 51510176.0.
# Iteration 6, inertia 51368588.0.
# Iteration 7, inertia 51259248.0.
# Iteration 8, inertia 51178168.0.
# Iteration 9, inertia 51114428.0.
# Iteration 10, inertia 51064716.0.
# Iteration 11, inertia 51024132.0.
# Iteration 12, inertia 50993244.0.
# Iteration 13, inertia 50968808.0.
# Iteration 14, inertia 50949344.0.
# Iteration 15, inertia 50933620.0.
# Iteration 16, inertia 50920816.0.
# Iteration 17, inertia 50909780.0.
# Iteration 18, inertia 50900092.0.
# Iteration 19, inertia 50891068.0.
# Iteration 20, inertia 50881712.0.
# Iteration 21, inertia 50869416.0.
# Iteration 22, inertia 50852456.0.
# Iteration 23, inertia 50844056.0.
# Iteration 24, inertia 50837408.0.
# Iteration 25, inertia 50831064.0.
# Iteration 26, inertia 50825208.0.
# Iteration 27, inertia 50819752.0.
# Iteration 28, inertia 50814940.0.
# Iteration 29, inertia 50810736.0.
# Iteration 30, inertia 50806968.0.
# Iteration 31, inertia 50803424.0.
# Iteration 32, inertia 50800176.0.
# Iteration 33, inertia 50797416.0.
# Iteration 34, inertia 50794812.0.
# Iteration 35, inertia 50792236.0.
# Iteration 36, inertia 50789812.0.
# Iteration 37, inertia 50787312.0.
# Iteration 38, inertia 50784484.0.
# Iteration 110, inertia 50680368.0.
# Iteration 111, inertia 50680356.0.
# Iteration 112, inertia 50680336.0.
# Iteration 113, inertia 50680320.0.
# Iteration 114, inertia 50680296.0.
# Iteration 115, inertia 50680288.0.
# Iteration 116, inertia 50680260.0.
# Iteration 117, inertia 50680248.0.
# Iteration 118, inertia 50680228.0.
# Iteration 119, inertia 50680208.0.
# Iteration 120, inertia 50680212.0.
# Iteration 121, inertia 50680212.0.
# Iteration 122, inertia 50680204.0.
# Iteration 123, inertia 50680220.0.
# Iteration 124, inertia 50680204.0.
# Iteration 125, inertia 50680196.0.
# Iteration 126, inertia 50680200.0.
# Iteration 127, inertia 50680200.0.
# Iteration 128, inertia 50680184.0.
# Iteration 129, inertia 50680168.0.
# Iteration 130, inertia 50680172.0.
# Iteration 131, inertia 50680172.0.
# Iteration 132, inertia 50680180.0.
# Iteration 133, inertia 50680176.0.
# Iteration 134, inertia 50680168.0.
# Iteration 135, inertia 50680148.0.
# Iteration 136, inertia 50680152.0.
# Iteration 137, inertia 50680156.0.
# Iteration 138, inertia 50680168.0.
# Iteration 139, inertia 50680172.0.
# Iteration 140, inertia 50680160.0.
# Iteration 141, inertia 50680160.0.
# Converged at iteration 141: center shift 0.0002799693320412189 within tolerance 0.0003486533403396607.
# KMeans(max_iter=400, n_clusters=500, random_state=20220609, verbose=3)

# %%
# Output the kmean fit
with open(work_dir / "clus_kmeans", "wb") as f:
  pickle.dump(clus_kmeans, f)

# %%
# Load kmean fit in case the session died.
with open(work_dir / "clus_kmeans", "rb") as f:
  clus_kmeans_loaded = pickle.load(f)

# %% [markdown]
# ### Spectral
#
# Run into memory problem
# - MemoryError: Unable to allocate 1.08 TiB for an array with shape (148010221199,) and data type int64
# - Do PCA first then run again.

# %%
cluster_spectral = SpectralClustering(n_clusters=500,
                                      assign_labels='discretize',
                                      random_state=seed, n_jobs=16, verbose=3)

# %%
cluster_spectral.fit(X_vec_norm_pca)

# %%
# Output the kmean fit
with open(work_dir / "clus_spectral", "wb") as f:
  pickle.dump(cluster_spectral, f)

# %%
# Load kmean fit in case the session died.
with open(work_dir / "clus_spectral", "rb") as f:
  clus_spectral_loaded = pickle.load(f)

# %% [markdown]
# ### HDBSCAN
#
# https://ml2021.medium.com/clustering-with-python-hdbscan-964fb8292ace

# %% [markdown]
# ### Subspace-clustering
#
# https://github.com/ChongYou/subspace-clustering
# - Run into issue:
#   - return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#   - ValueError: zero-size array to reduction operation maximum which has no identity

# %%
model = ElasticNetSubspaceClustering(n_clusters=1000, random_state=seed,
                                     algorithm='lasso_lars', n_jobs=16,
                                     gamma=50).fit(X_vec_norm_lil)

# %% [markdown]
# ## ___Not used___

# %% [markdown]
# ## ___N2d clustering___
#
# Did not try to figure out how to pass a sparse matrix...

# %% [markdown]
# ### Set up functions
#
# Based on [this post](https://towardsdatascience.com/deep-clustering-with-sparse-data-b2eb1bf2922e)

# %%
def get_autoencoder(dims, act='relu'):
    n_stacks = len(dims) - 1
    x = Input(shape=(dims[0],), name='input')

    h = x
    for i in range(n_stacks - 1):
        h = Dense(dims[i + 1], activation=act, name='encoder_%d' % i)(h)

    h = Dense(dims[-1], name='encoder_%d' % (n_stacks - 1))(h)
    for i in range(n_stacks - 1, 0, -1):
        h = Dense(dims[i], activation=act, name='decoder_%d' % i)(h)

    h = Dense(dims[0], name='decoder_0')(h)

    model = Model(inputs=x, outputs=h)
    model.summary()
    return model

# %%
def learn_manifold(x_data, umap_min_dist=0.00, umap_metric='euclidean', 
                   umap_dim=10, umap_neighbors=30):
    md = float(umap_min_dist)
    return umap.UMAP(
        random_state=0,
        metric=umap_metric,
        n_components=umap_dim,
        n_neighbors=umap_neighbors,
        min_dist=md).fit_transform(x_data)

# %% [markdown]
# ### Split train-test

# %%
X_train, X_test = train_test_split(X_vec_norm_df, test_size=0.2, 
                                   random_state=seed)

# %% [markdown]
# ### Initialize autoencoder

# %%
batch_size         = 256
pretrain_epochs    = 64
encoded_dimensions = 10
shape              = [X_vec_norm_df.shape[-1], 250, 250, 500, encoded_dimensions]
autoencoder        = get_autoencoder(shape)
shape

# %%
encoded_layer = f'encoder_{(len(shape) - 2)}'

print(f'taking the last encoder layer:{encoded_layer}')

hidden_encoder_layer = autoencoder.get_layer(name=encoded_layer).output
encoder              = Model(inputs=autoencoder.input, 
                             outputs=hidden_encoder_layer)
autoencoder.compile(loss='mse', optimizer='adam')

# %% [markdown]
# ### Train autoencoder

# %%
model_series = 'CLS_MODEL_' + datetime.now().strftime("%h%d%Y-%H%M")

checkpointer = ModelCheckpoint(filepath=f"{model_series}-model.h5", verbose=0, 
                               save_best_only=True)

autoencoder.fit(
    X_train,
    X_train,
    batch_size=batch_size,
    epochs=pretrain_epochs,
    verbose=1,
    validation_data=(X_test, X_test),
    callbacks=[checkpointer]
)

autoencoder = load_model(f"{model_series}-model.h5")

# %%
# save its weights
weights_name = 'weights/' + model_series + "-" + str(pretrain_epochs) + '-ae_weights.h5'
autoencoder.save_weights(weights_name)

# %%
# use the weights learned by the encoder to encode the data to a representation (embedding)
X_encoded = encoder.predict(X)

# %%
X_reduced = learn_manifold(X_encoded, umap_neighbors=30, 
                           umap_dim=int(encoded_dimensions/2))

# %%
# this is the data that we need to cluster
labels = hdbscan.HDBSCAN(
    min_samples=100,
    min_cluster_size=1000,
).fit_predict(X_reduced)

# %%
unique, counts = np.unique(labels, return_counts=True)
print (np.asarray((unique, counts)).T)

# %%
#important to note that the clustering was performed on the result of UMAP
# but the 2 dim lowering here (in order to generate the plot - was performed on the result of the encoder only)
reducer = umap.UMAP(n_components=2)
embedding = reducer.fit_transform(X_encoded)

# %%
fig = plt.figure(figsize=(12,8))
plt.scatter(reducer.embedding_[:, 0], reducer.embedding_[:, 1], c=labels, 
            cmap='tab20c')

viz_clusters = pd.DataFrame(embedding)
viz_clusters['cluster'] = labels

for row in viz_clusters.groupby('cluster').mean().reset_index().values:
    label = f'CLUSTER: {row[0]}'
    plt.annotate(label, (row[1], row[2]), textcoords="offset points", 
                 fontsize=12,  xytext=(25,0), ha='center')
