# %% [markdown]
# # __Minor revision__

# %%
import os
from pathlib import Path
import pandas as pd

# %%
proj_dir = Path.home() / "projects/plant_sci_hist/"

dir4  = proj_dir / "4_topic_model"
dir42 = dir4 / "4_2_outlier_assign"
dir43 = dir4 / "4_3_model_analysis"

dir2  = proj_dir / "2_text_classify"
dir25 = dir2 / "2_5_predict_pubmed"

dir95 = proj_dir / "9_wrap_up/9_5_minor_rev"
dir95.mkdir(exist_ok=True)

# %% [markdown]
# ## ___Recover Figure 1B info___
#
# The original BERTopic model could not be read back in due to version change. However, the topic assignment info is already incorported into the corpus file. So the counts are recovered from there.

# %%
# Read corpus file with topic assignment
corpus_file = dir42 / "table4_2_corpus_with_topic_assignment.tsv.gz"
corpus_df   = pd.read_csv(corpus_file, sep="\t", compression="gzip")

# %%
corpus_df.head(2)
# Out:
#    Unnamed: 0  Index_1385417  PMID        Date                        Journal  \
# 0           0              3    61  1975-12-11  Biochimica et biophysica acta
# 1           1              4    67  1975-11-20  Biochimica et biophysica acta
#
#                                                Title  \
# 0  Identification of the 120 mus phase in the dec...
# 1  Cholinesterases from plant tissues. VI. Prelim...
#
#                                             Abstract Initial filter qualifier  \
# 0  After a 500 mus laser flash a 120 mus phase in...                  spinach
# 1  Enzymes capable of hydrolyzing esters of thioc...                    plant
#
#                                               Corpus  reg_article  \
# 0  Identification of the 120 mus phase in the dec...            1
# 1  Cholinesterases from plant tissues. VI. Prelim...            1
#
#    Text classification score  \
# 0                   0.716394
# 1                   0.894874
#
#                                  Preprocessed corpus  Topic
# 0  identification 120 mus phase decay delayed flu...     52
# 1  cholinesterases plant tissues . vi . prelimina...     48

# %%
# Get topic counts
topic_counts = corpus_df["Topic"].value_counts().sort_index()
topic_counts = pd.DataFrame(topic_counts)
topic_counts.columns = ["Count"]
topic_counts.index.name = "Topic"

topic_counts.head(10)
# Out:
#        Count
# Topic
# -1     49228
#  0       895
#  1      2917
#  2      1098
#  3       751
#  4      4616
#  5       620
#  6      1977
#  7      1344
#  8      1057

# %%
# Get topic names
topic_name_file = dir43 / "fig4_3_topic_heatmap_seaborn_order.txt"

topic_name = pd.read_csv(topic_name_file, sep="\t", header=None,
                        names=["Topic", "Name"], index_col="Topic")

# sort topic_name based on index
topic_name = topic_name.reindex(topic_counts.index)

topic_name.head(10)
# Out:
#                                                     Name
# Topic
# -1     |plant|plants|genes|cell|expression|gene|prote...
#  0     |allergen|allergens|pollen|ige|patients|bet|al...
#  1     |medium|callus|regeneration|mgl|ms|culture|som...
#  2     |dots|fluorescence|detection|carbon dots|carbo...
#  3     |glyphosate|resistance|herbicide|herbicides|re...
#  4     |uvb|stress|plants|radiation|leaves|increased|...
#  5     |bp|chloroplast genome|complete chloroplast|ge...
#  6     |cell|cells|imaging|microscopy|plant|proteins|...
#  7     |cells|cell|wall|pollen|cellulose|gravity|cyto...
#  8     |genome sequence|genome|draft|draft genome|str...

# %%
# merge topic_counts and topic_name
topic_count_name = pd.merge(topic_counts, topic_name, left_index=True, right_index=True)

# %%
topic_count_name.head(10)
# Out:
#        Count                                               Name
# Topic
# -1     49228  |plant|plants|genes|cell|expression|gene|prote...
#  0       895  |allergen|allergens|pollen|ige|patients|bet|al...
#  1      2917  |medium|callus|regeneration|mgl|ms|culture|som...
#  2      1098  |dots|fluorescence|detection|carbon dots|carbo...
#  3       751  |glyphosate|resistance|herbicide|herbicides|re...
#  4      4616  |uvb|stress|plants|radiation|leaves|increased|...
#  5       620  |bp|chloroplast genome|complete chloroplast|ge...
#  6      1977  |cell|cells|imaging|microscopy|plant|proteins|...
#  7      1344  |cells|cell|wall|pollen|cellulose|gravity|cyto...
#  8      1057  |genome sequence|genome|draft|draft genome|str...

# %%
# Save dataframe as csv
topic_count_name_file = dir95 / "fig1b_topic_count_name.csv"
topic_count_name.to_csv(topic_count_name_file)

# %% [markdown]
# ## ___Figure S1___

# %% [markdown]
# ### S1D

# %%
pubmed_pred_prob_file = \
  dir25 / "pubmed_qual_1384718_w2v_pred_prob_CORRECTED.tsv.gz"
pubmed_pred_prob_df = \
  pd.read_csv(pubmed_pred_prob_file, sep="\t", compression="gzip")
pubmed_pred_prob_df.head()
# Out:
#    Unnamed: 0  PMID        Date                           Journal  \
# 0           0    36  1975-11-01  The British journal of nutrition
# 1           1    52  1975-12-02                      Biochemistry
# 2           2    60  1975-12-11     Biochimica et biophysica acta
# 3           3    61  1975-12-11     Biochimica et biophysica acta
# 4           4    67  1975-11-20     Biochimica et biophysica acta
#
#                                                Title  \
# 0  The effects of processing of barley-based supp...
# 1  Evidence of the involvement of a 50S ribosomal...
# 2  The reaction between the superoxide anion radi...
# 3  Identification of the 120 mus phase in the dec...
# 4  Cholinesterases from plant tissues. VI. Prelim...
#
#                                             Abstract QualifiedName  \
# 0  1. In one experiment the effect on rumen pH of...        barley
# 1  The functional role of the Bacillus stearother...          rose
# 2  1. The superoxide anion radical (O2-) reacts w...          tuna
# 3  After a 500 mus laser flash a 120 mus phase in...       spinach
# 4  Enzymes capable of hydrolyzing esters of thioc...         plant
#
#                                                  txt  reg_article    y_prob  \
# 0  The effects of processing of barley-based supp...            1  0.162140
# 1  Evidence of the involvement of a 50S ribosomal...            1  0.286834
# 2  The reaction between the superoxide anion radi...            1  0.248357
# 3  Identification of the 120 mus phase in the dec...            1  0.716394
# 4  Cholinesterases from plant tissues. VI. Prelim...            1  0.894874
#
#    y_pred
# 0       0
# 1       0
# 2       0
# 3       1
# 4       1

# %%
# Get pmid, y_prob from pubmed_pred_prob_df
pubmed_pred_prob_df_select = pubmed_pred_prob_df[["PMID", "y_prob"]]
pubmed_pred_prob_df_select.head()
# Out:
#    PMID    y_prob
# 0    36  0.162140
# 1    52  0.286834
# 2    60  0.248357
# 3    61  0.716394
# 4    67  0.894874

# %%
pubmed_pred_prob_df_select.to_csv(
  dir95 / "fig_s1d_pubmed_pred_prob.csv", index=False)

# %% [markdown]
# ## ___Additional analysis on 12 benchmark journal___

# %%
j_positive_nt = [
  'Current opinion in plant biology',
  'Trends in plant science',
  'Functional plant biology : FPB',
  'Molecular plant pathology',
  'Molecular plant',
  'Journal of integrative plant biology',
  'Journal of plant research',
  'Physiology and molecular biology of plants : an international journal of '+\
    'functional plant biology',
  'Nature plants',
  'The plant pathology journal',
  'Annual review of plant biology',
  'The plant genome']

# %%
corpus_cand_df_file = dir25 / f"pubmed_qual_1384718_w2v_pred_prob_CORRECTED.tsv.gz"
corpus_cand_df = pd.read_csv(corpus_cand_df_file, sep="\t", compression="gzip")

# %%
corpus_cand_df.shape
# Out:
# (1384717, 11)

# %%
# Get records with journal names in j_positive_nt
corpus_df_j12 = corpus_cand_df[corpus_cand_df["Journal"].isin(j_positive_nt)]

corpus_df_j12.shape
# Out:
# (12611, 11)

# %%
import numpy as np

corpus_df_j12_pred_false = corpus_df_j12["y_pred"] == 0
num_fn = np.sum(corpus_df_j12_pred_false)

tpr = 1 - num_fn / corpus_df_j12.shape[0]
tpr
# Out:
# 0.902862580287051

# %% [markdown]
# ## ___Additional analysis on our own paper___

# %%
pmid_shiu_sh = \
[11526204,
11752632,
12169662,
12805585,
14657406,
14963097,
15105442,
15653807,
16166257,
16461903,
17010199,
17091126,
17098053,
17189345,
17284581,
17395691,
17466346,
17530419,
17555994,
17652332,
17720868,
18079367,
22303237,
18369451,
18715958,
19136648,
19321712,
19641029,
19649161,
20008477,
20152032,
20935180,
22629272,
21297981,
21511909,
21549954,
21849619,
22025705,
22072962,
22383541,
22443345,
22496844,
22889912,
23132786,
23166516,
23431200,
24082131,
24306534,
24876251,
24903334,
25354782,
25384563,
25880851,
25918418,
25986129,
26063739,
26103993,
26216534,
26286535,
26291518,
26586835,
26826726,
27098848,
27288366,
27522016,
27935950,
28295310,
28373393,
28398576,
28542203,
28761000,
29288234,
29554332,
29743197,
30239695,
30674669,
30718437,
30866803,
31431676,
31533955,
31551359,
31641024,
31937681,
32054475,
32170020,
32396837,
32613943,
32817425,
33344884,
33530937,
33575601,
33681966,
33749860,
33871641,
34354723,
34716496,
34865154,
35078130,
35218008,
35832206,
36001691,
36156105,
36299783,
37126718,
37918732]

# %%
len(pmid_shiu_sh)
# Out:
# 105

# %%
# get records with pmid in pmid_shiu_sh
corpus_df_shiu_sh = corpus_cand_df[corpus_cand_df["PMID"].isin(pmid_shiu_sh)]
corpus_df_shiu_sh.shape
# Out:
# (70, 11)

# %%
# remove unnamed: 0 column
corpus_df_shiu_sh = corpus_df_shiu_sh.loc[:, ~corpus_df_shiu_sh.columns.str.contains('Unnamed: 0')]

corpus_df_shiu_sh.to_csv(dir95 / "corpus_df_shiu_sh.csv", index=False)

# %% [markdown]
# ## ___Reviewer suggested analysis___
#
# Reviewer 1 suggested we:
# - Randomly select 50 predicted positives and 50 predicted negatives,
# - Provde only titles and abstracts,
# - Have other colleagues to annotate these records.

# %%
# randomly select 50 positive and negative records from corpus_cand_df
corpus_df_pos = corpus_cand_df[corpus_cand_df["y_pred"] == 1]
corpus_df_pos_sample = corpus_df_pos.sample(n=50, random_state=240330)
corpus_df_pos_sample = corpus_df_pos_sample[["PMID", "Title", "Abstract", "y_prob"]]
corpus_df_pos_sample.to_csv(dir95 / "corpus_df_pos_sample.csv", index=False)

corpus_df_pos_sample_for_annotator = corpus_df_pos_sample[["Title", "Abstract"]]
corpus_df_pos_sample_for_annotator.to_csv(dir95 / "corpus_df_pos_sample_for_annotator.csv", index=False)

corpus_df_neg = corpus_cand_df[corpus_cand_df["y_pred"] == 0]
corpus_df_neg_sample = corpus_df_neg.sample(n=50, random_state=240330)
corpus_df_neg_sample = corpus_df_neg_sample[["PMID", "Title", "Abstract", "y_prob"]]
corpus_df_neg_sample.to_csv(dir95 / "corpus_df_neg_sample.csv", index=False)

corpus_df_neg_sample_for_annotator = corpus_df_neg_sample[["Title", "Abstract"]]
corpus_df_neg_sample_for_annotator.to_csv(dir95 / "corpus_df_neg_sample_for_annotator.csv", index=False)

# %%
corpus_df_pos_sample
# Out:
#          Unnamed: 0      PMID        Date  \
# 944456      1027528  26379678  2015-09-18
# 673928       751582  21642137  2006-05-01
# 1019550     1104213  27733112  2016-10-14
# 1153083     1241192  30007612  2018-07-17
# 449867       515287  16667194  1989-12-01
# 1074530     1160472  28668976  2017-07-03
# 1081098     1167172  28775794  2017-08-05
# 944128      1027195  26374125  2015-09-17
# 719521       798138  22504550  2012-04-17
# 704079       782349  22214659  2012-01-05
# 925984      1008655  26053748  2015-06-09
# 815205       895654  24223281  2013-11-14
# 752456       831764  23151272  2012-11-16
# 1138767     1226389  29741016  2017-03-18
# 259379       301121  10732679  2000-03-25
# 565918       638971  19259272  2009-03-05
# 352049       397954  12970485  2003-09-13
# 1078478     1164505  28734048  2017-07-25
# 933556      1016385  26188664  2015-07-21
# 46755         54096   1895057  1991-09-01
# 595911       669753  19850118  2009-10-24
# 1121458     1208715  29453559  2018-02-18
# 588187       661841  19700546  2009-08-25
# 470484       536917  17094968  2006-11-11
# 747710       826941  23065054  2012-10-16
# 1019988     1104664  27742648  2016-10-16
# 743852       823013  22988090  2012-09-19
# 1042777     1127969  28208301  2017-02-18
# 1165845     1254253  30202433  2018-09-12
# 1327829     1419289  32552518  2020-06-20
# 1240764     1330723  31245717  2018-04-14
# 1286977     1377718  31936926  1994-01-01
# 283531       326316  11319099  2001-04-25
# 494547       562062  17598084  2007-06-29
# 476355       542962  17215898  2007-01-12
# 492563       560005  17556080  2007-06-09
# 1270558     1361020  31701654  2019-11-09
# 1219400     1308979  30926851  2019-03-31
# 482925       550028  17349112  2007-03-14
# 957749      1041076  26606587  2015-11-26
# 565918   Genetic structure of the polymorphic metroside...
# 352049   Functional characterization and expression ana...
# 1078478  Non-anthocyanin polyphenolic transformation by...
# 933556   Temperature profile in apricot tree canopies u...
# 46755    The phylogeny of RNA-dependent RNA polymerases...
# 595911   Ripening of fleshy fruit: molecular insight an...
# 1121458  Regulation of H+-pyrophosphatase by 14-3-3 Pro...
# 588187   ACC (1-aminocyclopropane-1-carboxylate) deamin...
# 470484   Structure determinants and substrate recogniti...
# 747710   Ectopic expression of the ABA-inducible dehydr...
# 1019988  Geographical distance and barriers explain pop...
# 743852   Integration of stress-related and reactive oxy...
# 1042777  Biomolecular Interaction Assays Identified Dua...
# 1165845  Addition of β-galactosidase boosts the xyloglu...
# 1327829  Chromosome-Scale Genome Assembly of Fusarium o...
# 1240764  Ectopic expression of the PISTILLATA homologou...
# 1286977  Infanticide among ringtailed lemurs (Lemur cat...
# 283531   Molecular characterization of an endopolygalac...
# 494547   Potential causes of linkage disequilibrium in ...
# 476355   Molecular characterization and expression prof...
# 492563   Roles of dynamic and reversible histone acetyl...
# 1270558  mRNA 3' end formation in plants: Novel connect...
# 1219400  Transcriptional response of grapevine to infec...
# 482925   Soil potassium deficiency affects soybean phlo...
# 957749   Rapid Diagnosis of Soybean Seedling Blight Cau...
# 638321   Alkylresorcinol biosynthesis in plants: new in...
# 245474   EIN2, a bifunctional transducer of ethylene an...
# 1028344  Function-Based Metagenomic Library Screening a...
# 421305   Recruitment of CRABS CLAW to promote nectary d...
# 505182   Tri-trophic consequences of UV-B exposure: pla...
# 1305268  Brassica incana Ten. (Brassicaceae): Phenolic ...
# 1064561  Two new species of Begonia sect. Coelocentrum,...
# 953505   Expression of the Rice Arginase Gene OsARG in ...
# 1042850  Metabolomic approach reveals the biochemical m...
# 222872   In situ dry matter, nitrogen, and fiber degrad...
#
#                                                   Abstract     QualifiedName  \
# 944456   Acacia ampliceps (salt wattle), a leguminous s...            acacia
# 673928   Models of the evolution of gynodioecy assume t...             plant
# 1019550  Predicted climate changes announce an increase...            plants
# 1153083  This study explored the interaction of pectin ...             olive
# 449867   Proteolytic activity in oat leaf extracts was ...               oat
# 1074530  Whereas proline accumulates through de novo bi...            plants
# 1081098  The genetic platforms of Deinococcus species r...              mate
# 944128   Bacterial SH3 (SH3b) domains are commonly fuse...              dock
# 719521   The mountain pine beetle (MPB; Dendroctonus po...     mountain pine
# 704079   Plants modify their growth and development to ...            plants
# 925984   In energy crops for biomass production a prope...            poplar
# 815205   Wheat (Triticum aestivum L.) is one of the mos...             wheat
# 752456   Most aerial plant parts are covered with a hyd...             plant
# 1138767  Photosynthesis characteristics of winter wheat...             wheat
# 259379   We investigated transgene silencing in a line ...              rice
# 565918   Five species of Metrosideros (Myrtaceae) are r...            plants
# 352049   A genomic clone and the corresponding cDNA of ...            plants
# 1078478  Co-inoculation has been adapted by many wine-p...             grape
# 933556   The paper describes the temperature profiles d...           apricot
# 46755    Representative amino acid sequences of the RNA...              beet
# 595911   Development and ripening in fruit is a unique ...     higher plants
# 1121458  Plant vacuolar H+-transporting inorganic pyrop...             plant
# 588187   The genus Burkholderia includes pathogens of p...            plants
# 470484   Structures of the serine carboxypeptidase-like...             plant
# 747710   Myo-inositol participates in many different as...             plant
# 1019988  Island plants are frequently used as model sys...            plants
# 743852   Environmental stress often leads to an increas...            plants
# 1042777  Glutaminase (KGA/isoenzyme GAC) is an emerging...            radish
# 1165845  Increasing the efficiency of enzymatic biomass...             plant
# 1327829  Here, we report a chromosome-level genome asse...             plant
# 1240764  Fruit shape represents a key trait that consum...             apple
# 1286977  During an intertroop encounter, an infanticide...              mate
# 283531   The tomato vascular wilt pathogen Fusarium oxy...             plant
# 494547   Knowledge about the forces generating and cons...             maize
# 476355   Penicillium griseoroseum has been studied by o...             apple
# 492563   Transcriptional regulation in eukaryotes is no...             plant
# 1270558  3' end processing and mRNA polyadenylation is ...            plants
# 1219400  Botryosphaeria dieback on the grapevine is cau...             grape
# 482925   The soybean aphid is an invasive pest in the m...           soybean
# 957749   A new method of direct detection of pathogenic...           soybean
# 638321   Alkylresorcinols are members of an extensive f...             plant
# 245474   Ethylene regulates plant growth, development, ...             plant
# 1028344  The release of phosphate from inorganic and or...             plant
# 421305   Nectaries are secretory organs that are widely...  flowering plants
# 505182   In this paper we demonstrate a UV-B-mediated l...             plant
# 1305268  Brassica incana Ten. is an edible plant belong...             plant
# 1064561  In our recent molecular phylogenetic study of ...           begonia
# 953505   Arginase is the only enzyme capable of produci...              rice
# 1042850  Thyme as a perennial herb has been recognized ...             thyme
# 222872   This study compared in situ degradation charac...        red clover
#
#                                                        txt  reg_article  \
# 944456   Physio-biochemical and morphological character...            1
# 673928   Inbreeding effect on male and female fertility...            1
# 1019550  Transcriptomic comparison between two Vitis vi...            1
# 1153083  Molecular interactions between 3,4-dihydroxyph...            1
# 449867   Proteolytic Activity at Alkaline pH in Oat Lea...            1
# 1074530  Abscisic acid-regulated protein degradation ca...            1
# 1081098  High-quality genome sequence of the radioresis...            1
# 944128   Insights into Substrate Specificity of NlpC/P6...            1
# 719521   Mountain pine beetle develops an unprecedented...            1
# 704079   Arabidopsis ubiquitin conjugase UBC32 is an ER...            1
# 925984   Matching the best viewing angle in depth camer...            1
# 815205   Did the house mouse (Mus musculus L.) shape th...            1
# 752456   Estimation of the solubility parameters of mod...            1
# 1138767  [Effects of tillage practices on photosyntheti...            1
# 259379   Alternative silencing effects involve distinct...            1
# 565918   Genetic structure of the polymorphic metroside...            1
# 352049   Functional characterization and expression ana...            1
# 1078478  Non-anthocyanin polyphenolic transformation by...            1
# 933556   Temperature profile in apricot tree canopies u...            1
# 46755    The phylogeny of RNA-dependent RNA polymerases...            1
# 595911   Ripening of fleshy fruit: molecular insight an...            1
